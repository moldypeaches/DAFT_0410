# %%
import pandas as pd
male = pd.read_csv('male_clean.csv')

# %%
male
# Out:
#                                  genres      id original_language  \
# 0                       Comedy, Romance   11860           English
# 1                        Comedy, Horror   12110           English
# 2                     Action, Adventure    1408           English
# 3                          Drama, Crime     524           English
# 4                        Drama, Romance    4584           English
# ...                                 ...     ...               ...
# 9764   Drama, Thriller, Mystery, Horror  365432           English
# 9765  Action, Thriller, Mystery, Horror   45527           English
# 9766            Drama, Family, TV Movie   39562           English
# 9767                             Comedy   14008           English
# 9768             Action, Drama, Romance   30840           English
#
#                                                overview  popularity  \
# 0     An ugly duckling having undergone a remarkable...    6.677277
# ...

# %% [markdown]
# #Films

# %%
films = male[['id', 'title','original_language', 'overview', 'year']]

# %%
films
# Out:
#           id                        title original_language  \
# 0      11860                      Sabrina           English
# 1      12110  Dracula: Dead and Loving It           English
# 2       1408             Cutthroat Island           English
# 3        524                       Casino           English
# 4       4584        Sense and Sensibility           English
# ...      ...                          ...               ...
# 9764  365432                   The Sublet           English
# 9765   45527              The Final Storm           English
# 9766   39562            To Be Fat Like Me           English
# 9767   14008                  Cadet Kelly           English
# 9768   30840                   Robin Hood           English
#
#                                                overview  year
# 0     An ugly duckling having undergone a remarkable...  1995
# 1     When a lawyer shows up at the vampire's doorst...  1995
# ...

# %% [markdown]
# #Genres

# %%
genres = male[['genres']]

# %%
genres
# Out:
#                                  genres
# 0                       Comedy, Romance
# 1                        Comedy, Horror
# 2                     Action, Adventure
# 3                          Drama, Crime
# 4                        Drama, Romance
# ...                                 ...
# 9764   Drama, Thriller, Mystery, Horror
# 9765  Action, Thriller, Mystery, Horror
# 9766            Drama, Family, TV Movie
# 9767                             Comedy
# 9768             Action, Drama, Romance
#
# [9769 rows x 1 columns]

# %%
male['genres'].unique()
# Out:
# array(['Comedy, Romance', 'Comedy, Horror', 'Action, Adventure',
#        'Drama, Crime', 'Drama, Romance',
#        'Action, Crime, Adventure, Thriller', 'Drama',
#        'Adventure, Fantasy, Science Fiction', 'Drama, Romance, History',
#        'Drama, War', 'Drama, Foreign', 'Comedy, Drama, Romance',
#        'Drama, Thriller, Mystery', 'Drama, History', 'Drama, Family',
#        'Comedy', 'Action, Drama, Adventure, Thriller, Science Fiction',
#        'Documentary', 'Comedy, Drama, Family',
#        'Comedy, Action, Crime, Thriller', 'Drama, Romance, War',
#        'Comedy, Drama, Crime, Thriller', 'Adventure', 'Comedy, Action',
#        'Comedy, Drama', 'Thriller, Foreign', 'Drama, Romance, Family',
#        'Drama, Mystery', 'Action, Drama, Crime, Thriller',
#        'Drama, Fantasy', 'Comedy, Drama, History',
#        'Drama, Romance, Science Fiction, Horror', 'Horror',
#        'Drama, Crime, Thriller', 'Action, Western', 'Drama, Horror',
# ...

# %%
male['director'].value_counts()
# Out:
# Werner Herzog               44
# Jean-Luc Godard             40
# Ingmar Bergman              36
# Rainer Werner Fassbinder    30
# Akira Kurosawa              28
#                             ..
# Justin Dix                   1
# James Cameron                1
# John Flynn                   1
# Jem Cohen                    1
# Larry Shaw                   1
# Name: director, Length: 3785, dtype: int64
