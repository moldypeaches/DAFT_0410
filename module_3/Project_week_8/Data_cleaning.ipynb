# %% [markdown]
# ## Importing libraries

# %%
import pandas as pd
films = pd.read_csv('movies_clean.csv')

# %%
films[['genres', 'production_countries']]
# Out:
#                                                  genres  \
# 0     [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# 1     [{'id': 35, 'name': 'Comedy'}, {'id': 27, 'nam...
# 2     [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 3     [{'id': 18, 'name': 'Drama'}, {'id': 80, 'name...
# 4     [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# ...                                                 ...
# 9773  [{'id': 9648, 'name': 'Mystery'}, {'id': 18, '...
# 9774  [{'id': 28, 'name': 'Action'}, {'id': 9648, 'n...
# 9775  [{'id': 18, 'name': 'Drama'}, {'id': 10751, 'n...
# 9776                     [{'id': 35, 'name': 'Comedy'}]
# 9777  [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name...
#
#                                    production_countries
# 0     [{'iso_3166_1': 'DE', 'name': 'Germany'}, {'is...
# 1     [{'iso_3166_1': 'FR', 'name': 'France'}, {'iso...
# 2     [{'iso_3166_1': 'FR', 'name': 'France'}, {'iso...
# 3     [{'iso_3166_1': 'FR', 'name': 'France'}, {'iso...
# 4     [{'iso_3166_1': 'GB', 'name': 'United Kingdom'...
# ...                                                 ...
# 9773           [{'iso_3166_1': 'CA', 'name': 'Canada'}]
# 9774  [{'iso_3166_1': 'CA', 'name': 'Canada'}, {'iso...
# 9775           [{'iso_3166_1': 'CA', 'name': 'Canada'}]
# 9776  [{'iso_3166_1': 'CA', 'name': 'Canada'}, {'iso...
# 9777  [{'iso_3166_1': 'CA', 'name': 'Canada'}, {'iso...
#
# [9778 rows x 2 columns]

# %% [markdown]
# ## Null Values

# %%
films.isnull().sum()
# Out:
# genres                  0
# id                      0
# original_language       0
# original_title          0
# overview                0
# popularity              0
# poster_path             0
# production_companies    0
# production_countries    0
# release_date            0
# runtime                 0
# spoken_languages        0
# title                   0
# vote_average            0
# vote_count              0
# cast                    0
# crew                    0
# year                    0
# director                0
# director_gender         0
# dtype: int64

# %%
films.isna().sum()
# Out:
# genres                  0
# id                      0
# original_language       0
# original_title          0
# overview                0
# popularity              0
# poster_path             0
# production_companies    0
# production_countries    0
# release_date            0
# runtime                 0
# spoken_languages        0
# title                   0
# vote_average            0
# vote_count              0
# cast                    0
# crew                    0
# year                    0
# director                0
# director_gender         0
# dtype: int64

# %% [markdown]
# ## Drop Duplicates

# %%
films.drop_duplicates(subset='id', inplace=True)
films['id'].value_counts()
# Out:
# 11860     1
# 167956    1
# 68744     1
# 44023     1
# 84508     1
#          ..
# 43389     1
# 14298     1
# 9381      1
# 16182     1
# 30840     1
# Name: id, Length: 9769, dtype: int64

# %% [markdown]
# ## Investigating outliers

# %%
films['vote_average'].sort_values()
# Out:
# 6057     0.0
# 3785     0.0
# 8053     0.0
# 9301     0.0
# 3081     0.0
#         ...
# 8434    10.0
# 5357    10.0
# 4987    10.0
# 3960    10.0
# 7827    10.0
# Name: vote_average, Length: 9769, dtype: float64

# %%
# I decided to drop this column, as well as "vote_count" because I saw that "Call Me by Your Name", a very popular film, had a vote average 0. I will keep the column "popularity" which is more reliable, with a value of 4.300874.
films[films['vote_average'] == 0.0]
#male.drop(columns=['vote_average','vote_count'], inplace=True)
# Out:
#                                                  genres      id  \
# 3081  [{'id': 18, 'name': 'Drama'}, {'id': 10770, 'n...  111744
# 3785                     [{'id': 35, 'name': 'Comedy'}]  252407
# 4322  [{'id': 18, 'name': 'Drama'}, {'id': 14, 'name...   63702
# 6057                      [{'id': 18, 'name': 'Drama'}]   56178
# 6405  [{'id': 18, 'name': 'Drama'}, {'id': 36, 'name...   66963
# 6772                  [{'id': 12, 'name': 'Adventure'}]   95029
# 7141  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...  212934
# 7426  [{'id': 10770, 'name': 'TV Movie'}, {'id': 37,...   86543
# 8053                      [{'id': 18, 'name': 'Drama'}]  299143
# 9253  [{'id': 10749, 'name': 'Romance'}, {'id': 18, ...  398818
# 9301                      [{'id': 18, 'name': 'Drama'}]  429732
#
#      original_language                                     original_title  \
# 3081           English                                        Joe and Max
# 3785           English                                         Ich und Er
# 4322            French                                             Liliom
# 6057            French                                     Prix de beauté
# 6405            French                                     Lucrèce Borgia
# 6772           English                                  The Hellfire Club
# 7141           English  Behind the Camera: The Unauthorized Story of '...
# 7426           English                                          Rose Hill
# 8053           Italian                                 La porta del cielo
# 9253           English                               Call Me by Your Name
# 9301            French                                     Ana, mon amour
#
#                                                overview  popularity  \
# 3081  True story of boxers Joe Louis and Max Schmeli...    1.669115
# 3785  A man's enthusiastic penis starts talking to h...    0.645652
# 4322  Two women love the same man in a world of few ...    0.157182
# 6057  Lucienne, typist and gorgeous bathing beauty, ...    0.444066
# 6405  French silent film pioneer Abel Gance directs ...    0.142167
# 6772  Years after fleeing his ancestral home with hi...    0.177689
# 7141  An inside look at the ABC sitcom which turned ...    0.088172
# 7426  Four orphan boys running from the law in New Y...    0.625766
# 8053  Episodic film about the lives of a few people ...    0.040130
# 9253  Elio Perlman is spending the summer with his f...    4.300874
# 9301  Toma and Ana meet as students in the literatur...    2.160256
#
#                            poster_path  \
# 3081  /7aFWwYhxLSJU697MrXqpFC3jcqH.jpg
# 3785  /4JAz0lgfvDCzcgRB7eitix1jHyB.jpg
# 4322  /t0HejaSQ5bA5MVHltbR2WcBGTGm.jpg
# 6057  /i77kPa6IEv163tQsv2mdkE7oeoP.jpg
# 6405  /gu2mFsiFibXQxI6uMuAvgXXu48S.jpg
# 6772  /94GJm7vrEnib3uQnPd9mHkoVA6E.jpg
# 7141  /riywxnAgayG4HnzQLetHz6AsCsm.jpg
# 7426  /pxr4A8buPQqX41x58vRCubZg2pz.jpg
# 8053  /jkwP3EDGUpkYB8k3uBe5NO4GIGn.jpg
# 9253  /tcNniniS4rfqrLH0oORikJfnIwY.jpg
# 9301  /dd4QBIrLMxDpCdoj7LdWzRwuygN.jpg
#
#                                    production_companies  \
# 3081                                                 []
# 3785    [{'name': 'Neue Constantin Film', 'id': 13096}]
# 4322  [{'name': 'Les Productions Fox Europa', 'id': ...
# 6057                                                 []
# 6405                                                 []
# 6772   [{'name': 'New World Productions', 'id': 45641}]
# 7141  [{'name': 'NBC Studios', 'id': 7928}, {'name':...
# 7426  [{'name': 'Hallmark Hall of Fame Productions',...
# 8053  [{'name': 'Orbis Film', 'id': 36389}, {'name':...
# 9253  [{'name': 'Sony Pictures Classics', 'id': 58},...
# 9301  [{'name': 'Sophie Dulac Productions', 'id': 18...
#
#                                    production_countries release_date  runtime  \
# 3081  [{'iso_3166_1': 'US', 'name': 'United States o...   2002-03-03    109.0
# 3785          [{'iso_3166_1': 'DE', 'name': 'Germany'}]   1988-09-14     93.0
# 4322           [{'iso_3166_1': 'FR', 'name': 'France'}]   1934-05-15    118.0
# 6057           [{'iso_3166_1': 'FR', 'name': 'France'}]   1930-01-01     93.0
# 6405           [{'iso_3166_1': 'FR', 'name': 'France'}]   1935-12-20     93.0
# 6772   [{'iso_3166_1': 'GB', 'name': 'United Kingdom'}]   1961-02-03     90.0
# 7141           [{'iso_3166_1': 'CA', 'name': 'Canada'}]   2005-04-14    120.0
# 7426  [{'iso_3166_1': 'US', 'name': 'United States o...   1997-04-20     90.0
# 8053            [{'iso_3166_1': 'IT', 'name': 'Italy'}]   1945-02-16     88.0
# 9253  [{'iso_3166_1': 'BR', 'name': 'Brazil'}, {'iso...   2017-10-27    130.0
# 9301  [{'iso_3166_1': 'RO', 'name': 'Romania'}, {'is...   2017-03-03    127.0
#
#       spoken_languages                                              title  \
# 3081                 3                                        Joe and Max
# 3785                 0                                         Me and Him
# 4322                 1                                             Liliom
# 6057                 1                                       Beauty Prize
# 6405                 1                                    Lucrezia Borgia
# 6772                 1                                  The Hellfire Club
# 7141                 1  Behind the Camera: The Unauthorized Story of '...
# 7426                 1                                          Rose Hill
# 8053                 1                                 The Gate of Heaven
# 9253                 3                               Call Me by Your Name
# 9301                 2                                       Ana, My Love
#
#       vote_average  vote_count  \
# 3081           0.0         1.0
# 3785           0.0         1.0
# 4322           0.0         2.0
# 6057           0.0         1.0
# 6405           0.0         2.0
# 6772           0.0         1.0
# 7141           0.0         1.0
# 7426           0.0         1.0
# 8053           0.0         1.0
# 9253           0.0        18.0
# 9301           0.0         3.0
#
#                                                    cast  \
# 3081  [{'cast_id': 1001, 'character': 'Joe Louis', '...
# 3785  [{'cast_id': 1, 'character': 'Bert Uttanzi', '...
# 4322  [{'cast_id': 4, 'character': 'Liliom Zadowski'...
# 6057  [{'cast_id': 1001, 'character': 'Lucienne', 'c...
# 6405  [{'cast_id': 2, 'character': 'Lucrezia Borgia'...
# 6772  [{'cast_id': 4, 'character': 'Jason', 'credit_...
# 7141  [{'cast_id': 2, 'character': 'Robin Williams',...
# 7426  [{'cast_id': 2, 'character': 'Mary Rose Claybo...
# 8053  [{'cast_id': 0, 'character': 'The nurse', 'cre...
# 9253  [{'cast_id': 4, 'character': 'Elio Perlman', '...
# 9301  [{'cast_id': 5, 'character': 'Toma', 'credit_i...
#
#                                                    crew  year  \
# 3081  [{'credit_id': '593caed79251410587015f8b', 'de...  2002
# 3785  [{'credit_id': '5892039a9251412dc8008a19', 'de...  1988
# 4322  [{'credit_id': '52fe46b7c3a368484e09ffc1', 'de...  1934
# 6057  [{'credit_id': '52fe48f3c3a36847f8181d0b', 'de...  1930
# 6405  [{'credit_id': '52fe4752c3a368484e0c089b', 'de...  1935
# 6772  [{'credit_id': '54cf9dbc9251415cb8007196', 'de...  1961
# 7141  [{'credit_id': '52fe4dbac3a368484e1f9ab9', 'de...  2005
# 7426  [{'credit_id': '56d071a6c3a3681e44007122', 'de...  1997
# 8053  [{'credit_id': '5812de86c3a3687aa0020f68', 'de...  1945
# 9253  [{'credit_id': '5742ea0ec3a3686c8c001a6e', 'de...  2017
# 9301  [{'credit_id': '589fd3dfc3a3684e7b000278', 'de...  2017
#
#                 director director_gender
# 3081         Steve James            male
# 3785        Doris Dörrie          female
# 4322          Fritz Lang            male
# 6057      Augusto Genina            male
# 6405          Abel Gance            male
# 6772     Robert S. Baker            male
# 7141      Neill Fearnley            male
# 7426    Christopher Cain            male
# 8053    Vittorio De Sica            male
# 9253     Luca Guadagnino            male
# 9301  Călin Peter Netzer            male

# %%
#I checked the relevance of "popularity" column by checking the movies with lowest and highest rates.
films['popularity'].sort_values()
films['popularity'].sort_values(ascending=False)
films.loc[9462]
# Out:
# genres                  [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...
# id                                                                 339403
# original_language                                                 English
# original_title                                                Baby Driver
# overview                After being coerced into working for a crime b...
# popularity                                                     228.032744
# poster_path                              /dN9LbVNNZFITwfaRjl4tmwGWkRg.jpg
# production_companies    [{'name': 'Big Talk Productions', 'id': 443}, ...
# production_countries    [{'iso_3166_1': 'GB', 'name': 'United Kingdom'...
# release_date                                                   2017-06-28
# runtime                                                             113.0
# spoken_languages                                                        1
# title                                                         Baby Driver
# vote_average                                                          7.2
# vote_count                                                         2083.0
# cast                    [{'cast_id': 9, 'character': 'Baby', 'credit_i...
# crew                    [{'credit_id': '55c58c009251417a21000e5d', 'de...
# year                                                                 2017
# director                                                     Edgar Wright
# director_gender                                                      male
# Name: 9462, dtype: object

# %%
films[films['id'] == 321612]
# Out:
#                                                  genres      id  \
# 9246  [{'id': 10751, 'name': 'Family'}, {'id': 14, '...  321612
#
#      original_language        original_title  \
# 9246           English  Beauty and the Beast
#
#                                                overview  popularity  \
# 9246  A live-action adaptation of Disney's version o...  287.253654
#
#                            poster_path  \
# 9246  /tWqifoYuwLETmmasnGHO7xBjEtt.jpg
#
#                                    production_companies  \
# 9246  [{'name': 'Walt Disney Pictures', 'id': 2}, {'...
#
#                                    production_countries release_date  runtime  \
# 9246  [{'iso_3166_1': 'GB', 'name': 'United Kingdom'...   2017-03-16    129.0
#
#       spoken_languages                 title  vote_average  vote_count  \
# 9246                 1  Beauty and the Beast           6.8      5530.0
#
#                                                    cast  \
# 9246  [{'cast_id': 174, 'character': 'Belle', 'credi...
#
#                                                    crew  year     director  \
# 9246  [{'credit_id': '551879bec3a3681f840004eb', 'de...  2017  Bill Condon
#
#      director_gender
# 9246            male

# %%
films[films['id'] == 339403]
# Out:
#                                                  genres      id  \
# 9462  [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...  339403
#
#      original_language original_title  \
# 9462           English    Baby Driver
#
#                                                overview  popularity  \
# 9462  After being coerced into working for a crime b...  228.032744
#
#                            poster_path  \
# 9462  /dN9LbVNNZFITwfaRjl4tmwGWkRg.jpg
#
#                                    production_companies  \
# 9462  [{'name': 'Big Talk Productions', 'id': 443}, ...
#
#                                    production_countries release_date  runtime  \
# 9462  [{'iso_3166_1': 'GB', 'name': 'United Kingdom'...   2017-06-28    113.0
#
#       spoken_languages        title  vote_average  vote_count  \
# 9462                 1  Baby Driver           7.2      2083.0
#
#                                                    cast  \
# 9462  [{'cast_id': 9, 'character': 'Baby', 'credit_i...
#
#                                                    crew  year      director  \
# 9462  [{'credit_id': '55c58c009251417a21000e5d', 'de...  2017  Edgar Wright
#
#      director_gender
# 9462            male

# %%
films.groupby('id')['popularity'].sum().sort_values(ascending=False)[:10]
# Out:
# id
# 321612    287.253654
# 339403    228.032744
# 315837     68.726676
# 550        63.869599
# 406990     60.581223
# 440597     59.578823
# 403119     52.854103
# 360249     50.949523
# 353491     50.903593
# 258489     45.382980
# Name: popularity, dtype: float64

# %%
films = films.drop(films[films['popularity'] == 287.253654].index)
films = films.drop(films[films['popularity'] == 228.032744].index)

# %% [markdown]
# ## Fixing columns

# %%
def fix_genres_names(x):
    x = str(x)
    genres = []
    
    if 'Comedy' in x:
        genres.append('Comedy')
    if 'Action' in x:
        genres.append('Action')
    if 'Drama' in x:
        genres.append('Drama')
    if 'Crime' in x:
        genres.append('Crime')
    if 'Romance' in x:
        genres.append('Romance')
    if 'Adventure' in x:
        genres.append('Adventure')
    if 'Thriller' in x:
        genres.append('Thriller')
    if 'Fantasy' in x:
        genres.append('Fantasy')
    if 'Science Fiction' in x:
        genres.append('Science Fiction')
    if 'History' in x:
        genres.append('History')
    if 'War' in x:
        genres.append('War')
    if 'Foreign' in x:
        genres.append('Foreign')
    if 'Mystery' in x:
        genres.append('Mystery')
    if 'Family' in x:
        genres.append('Family')
    if 'Documentary' in x:
        genres.append('Documentary')
    if 'Horror' in x:
        genres.append('Horror')
    if 'Animation' in x:
        genres.append('Animation')
    if 'Western' in x:
        genres.append('Western')
    if 'Music' in x:
        genres.append('Music')
    if 'TV Movie' in x:
        genres.append('TV Movie')
    
    if genres:
        return ', '.join(genres)
    else:
        return 'nAn'

# %%
films['genres'] = films['genres'].apply(fix_genres_names)

# %%
#188 null values
films[films['genres'] ==  'nAn']
# Out:
#      genres      id original_language          original_title  \
# 171     nAn  172198         Hungarian            Bűvös vadász
# 182     nAn   42758           English             Small Faces
# 412     nAn   52907           English     Waltzes from Vienna
# 566     nAn   42020           Spanish           El amor brujo
# 652     nAn   67455            French     La nuit fantastique
# ...     ...     ...               ...                     ...
# 9621    nAn  254479           Chinese       Fish and Elephant
# 9661    nAn   56304           Russian             Сатисфакция
# 9677    nAn  143068           Russian  Станционный смотритель
# 9730    nAn   63320           English              Lions Love
# 9763    nAn  408624           English     A Death in the Gunj
#
#                                                overview  popularity  \
# 171   A battle-scarred, has-been Hungarian cop, torm...    0.091984
# 182   Three teenage brothers, gang-member Bobby, tro...    0.909130
# 412   The story of Johann Strauss the elder and youn...    0.751957
# 566   In a Gypsy village, the fathers of Candela and...    0.185772
# 652   Denis, a poor student in philosophy, works as ...    0.543794
# ...                                                 ...         ...
# 9621  The story follows the elephant keeper in the B...    0.436679
# 9661  Главный герой Александр, крупный бизнесмен и в...    0.468259
# 9677  In the early 19th century a traveler returns t...    0.002001
# 9730  “The pressures here in Hollywood are so great,...    0.112507
# 9763  A sensitive university student unraveling whil...    0.516993
#
#                            poster_path  \
# 171   /3phxETl3dV31eAbcML1pBt5x0EC.jpg
# 182   /s9I3gLu9ySsfyM3JvlpSW9KrszF.jpg
# 412   /jnXsVjBSfcgRxFOmxZpbwCe2Mrg.jpg
# 566   /8EA9bmQgeH6KUlsneql6GHydqYy.jpg
# 652   /bL2z18OIGyBOJacM2ZT37Xz52BK.jpg
# ...                                ...
# 9621  /mMNXeeEfqbJBVVWydKbWp2pgw16.jpg
# 9661  /sxsglmofLcRIZxacMmKiV8IoTBn.jpg
# 9677  /dJrO98IJsOe18E0LcVhioprSfDQ.jpg
# 9730  /s8r1oFBHcRymIDhwWKa4ysbiET7.jpg
# 9763  /ksqGltfJzYJL3lV4YvoIkVgcU55.jpg
#
#                                    production_companies  \
# 171   [{'name': 'Új Budapest Filmstudió', 'id': 1655...
# 182                                                  []
# 412   [{'name': 'Gaumont British Picture Corporation...
# 566                                                  []
# 652                                                  []
# ...                                                 ...
# 9621                                                 []
# 9661                                                 []
# 9677                  [{'name': 'Mosfilm', 'id': 5120}]
# 9730                                                 []
# 9763  [{'name': 'Studioz IDrream', 'id': 85800}, {'n...
#
#                                    production_countries release_date  runtime  \
# 171   [{'iso_3166_1': 'HU', 'name': 'Hungary'}, {'is...   1994-10-23    106.0
# 182    [{'iso_3166_1': 'GB', 'name': 'United Kingdom'}]   1996-04-05    108.0
# 412    [{'iso_3166_1': 'GB', 'name': 'United Kingdom'}]   1934-01-31     81.0
# 566             [{'iso_3166_1': 'ES', 'name': 'Spain'}]   1986-03-23    100.0
# 652            [{'iso_3166_1': 'FR', 'name': 'France'}]   1942-07-10    103.0
# ...                                                 ...          ...      ...
# 9621            [{'iso_3166_1': 'CN', 'name': 'China'}]   2001-09-01    106.0
# 9661           [{'iso_3166_1': 'RU', 'name': 'Russia'}]   2011-01-20     93.0
# 9677           [{'iso_3166_1': 'RU', 'name': 'Russia'}]   1972-08-25     68.0
# 9730  [{'iso_3166_1': 'US', 'name': 'United States o...   1969-09-20    110.0
# 9763            [{'iso_3166_1': 'IN', 'name': 'India'}]   2016-09-10    110.0
#
#       spoken_languages                title  vote_average  vote_count  \
# 171                  1         Magic Hunter           6.0         1.0
# 182                  1          Small Faces           6.4        10.0
# 412                  1  Waltzes from Vienna           4.8        11.0
# 566                  1        El Amor Brujo           7.0         4.0
# 652                  1  The Fantastic Night           5.7         3.0
# ...                ...                  ...           ...         ...
# 9621                 1    Fish and Elephant           4.8         4.0
# 9661                 1        Satisfaktsiya           5.6         4.0
# 9677                 1       The Postmaster           4.0         2.0
# 9730                 1           Lions Love           6.7         3.0
# 9763                 2  A Death in the Gunj           7.0         5.0
#
#                                                    cast  \
# 171   [{'cast_id': 4, 'character': 'Max', 'credit_id...
# 182   [{'cast_id': 1, 'character': 'Lex Maclean', 'c...
# 412   [{'cast_id': 2, 'character': 'Johann Strauss, ...
# 566   [{'cast_id': 4, 'character': 'Carmelo', 'credi...
# 652   [{'cast_id': 2, 'character': 'Denis', 'credit_...
# ...                                                 ...
# 9621                                                 []
# 9661  [{'cast_id': 1002, 'character': 'Dima', 'credi...
# 9677  [{'cast_id': 4, 'character': '', 'credit_id': ...
# 9730  [{'cast_id': 6, 'character': 'Viva', 'credit_i...
# 9763  [{'cast_id': 1, 'character': 'Shyamlal Chatter...
#
#                                                    crew  year  \
# 171   [{'credit_id': '52fe4d1bc3a36847f824efa5', 'de...  1994
# 182   [{'credit_id': '52fe4617c3a36847f80ec48d', 'de...  1996
# 412   [{'credit_id': '52fe4849c3a36847f815fbc1', 'de...  1934
# 566   [{'credit_id': '52fe45e9c3a36847f80e1a05', 'de...  1986
# 652   [{'credit_id': '52fe4767c3a368484e0c5137', 'de...  1942
# ...                                                 ...   ...
# 9621  [{'credit_id': '530368de92514121a45c5fff', 'de...  2001
# 9661  [{'credit_id': '52fe48f8c3a36847f8182b37', 'de...  2011
# 9677  [{'credit_id': '52fe4afb9251416c750f4617', 'de...  1972
# 9730  [{'credit_id': '52fe46a5c3a368484e09c077', 'de...  1969
# 9763  [{'credit_id': '58877d529251415ff70053e7', 'de...  2016
#
#                 director director_gender
# 171        Ildikó Enyedi          female
# 182    Gillies MacKinnon            male
# 412     Alfred Hitchcock            male
# 566         Carlos Saura            male
# 652     Marcel L'Herbier            male
# ...                  ...             ...
# 9621               Li Yu          female
# 9661        Anna Matison          female
# 9677     Sergey Solovyov            male
# 9730         Agnès Varda          female
# 9763  Konkona Sen Sharma          female
#
# [188 rows x 20 columns]

# %%
#Drop the null values in 'Genres'
films = films.drop(films[films['genres'] == 'nAn'].index)

# %%
films[films['genres'] ==  'nAn']
# Out:
# Empty DataFrame
# Columns: [genres, id, original_language, original_title, overview, popularity, poster_path, production_companies, production_countries, release_date, runtime, spoken_languages, title, vote_average, vote_count, cast, crew, year, director, director_gender]
# Index: []

# %%
#Fix production countries
films['prod_countries'] = films['production_countries'].str.extract(r"'name': '([^']*)'")
films['prod_countries'].unique()
# Out:
# array(['Germany', 'France', 'United Kingdom', 'Italy', 'China',
#        'United States of America', 'Canada', 'Belgium', 'Iran',
#        'Hong Kong', 'Dominican Republic', 'Ireland', 'Taiwan',
#        'New Zealand', 'Mexico', 'Japan', 'Peru', 'Australia',
#        'South Africa', 'Denmark', 'Finland', 'Spain', 'South Korea',
#        'Sweden', 'Argentina', 'Austria', 'Czech Republic', 'Vietnam',
#        'Switzerland', 'Trinidad and Tobago', 'Portugal', 'Russia',
#        'India', 'Brazil', 'Norway', 'Aruba', 'Israel', 'Luxembourg',
#        'Poland', 'Cuba', 'Malaysia', 'Bulgaria', 'Serbia', 'Greece',
#        'Thailand', 'Cameroon', 'Colombia', 'Netherlands', 'Philippines',
#        'Libyan Arab Jamahiriya', 'Iceland', 'Soviet Union', 'Turkey',
#        'Singapore', 'Bosnia and Herzegovina', 'Czechoslovakia',
#        'Martinique', 'Romania', 'Armenia', 'Egypt', 'Indonesia',
#        'Hungary', 'Chile', 'Monaco', 'Uruguay', 'Algeria', 'Lithuania',
#        'Palestinian Territory', 'East Germany', 'Morocco', 'Lebanon',
#        'Latvia', 'United Arab Emirates', 'Slovenia', 'Cambodia',
#        'Botswana', 'Pakistan', 'Congo', 'Tanzania', 'Bolivia',
#        'Kazakhstan', 'Ethiopia', 'Qatar', 'Tajikistan', 'Belarus',
#        'Estonia', 'Georgia', 'Mauritania', 'Burkina Faso', 'Afghanistan',
#        'Croatia', 'Yugoslavia', 'Malta', 'Nicaragua', 'Ukraine',
#        'Venezuela', 'Iraq', 'Liechtenstein', 'Albania', 'Macedonia'],
#       dtype=object)

# %%
    def fix_countries(x):
        x = str(x)
        genres = []
    
        if 'Germany' in x:
            genres.append('Germany')
        if 'France' in x:
            genres.append('France')
        if 'United Kingdom' in x:
            genres.append('United Kingdom')
        if 'Italy' in x:
            genres.append('Italy')
        if 'China' in x:
            genres.append('China')
        if 'United States of America' in x:
            genres.append('United States of America')
        if 'Canada' in x:
            genres.append('Canada')
        if 'Belgium' in x:
            genres.append('Belgium')
        if 'Iran' in x:
            genres.append('Iran')
        if 'Hong Kong' in x:
            genres.append('Hong Kong')
        if 'Dominican Republic' in x:
            genres.append('Dominican Republic')
        if 'Ireland' in x:
            genres.append('Ireland')
        if 'Taiwan' in x:
            genres.append('Taiwan')
        if 'New Zealand' in x:
            genres.append('New Zealand')
        if 'Mexico' in x:
            genres.append('Mexico')
        if 'Japan' in x:
            genres.append('Japan')
        if 'Peru' in x:
            genres.append('Peru')
        if 'Australia' in x:
            genres.append('Australia')
        if 'South Africa' in x:
            genres.append('South Africa')
        if 'Denmark' in x:
            genres.append('Denmark')
        if 'Finland' in x:
            genres.append('Finland')
        if 'Spain' in x:
            genres.append('Spain')
        if 'Sweden' in x:
            genres.append('Sweden')
        if 'South Korea' in x:
            genres.append('South Korea')
        if 'Sweden' in x:
            genres.append('Sweden')
        if 'Argentina' in x:
            genres.append('Argentina')
        if 'Hungary' in x:
            genres.append('Hungary')
        if 'Austria' in x:
            genres.append('Austria')
        if 'Czech Republic' in x:
            genres.append('Czech Republic')
        if 'Vietnam' in x:
            genres.append('Vietnam')
        if 'Switzerland' in x:
            genres.append('Switzerland')
        if 'Trinidad and Tobago' in x:
            genres.append('Trinidad and Tobago')
        if 'Portugal' in x:
            genres.append('Portugal')
        if 'Russia' in x:
            genres.append('Russia')
        if 'India' in x:
            genres.append('India')
        if 'Brazil' in x:
            genres.append('Brazil')
        if 'Norway' in x:
            genres.append('Norway')
        if 'Aruba' in x:
            genres.append('Aruba')
        if 'Israel' in x:
            genres.append('Israel')
        if 'Luxembourg' in x:
            genres.append('Luxembourg')
        if 'Poland' in x:
            genres.append('Poland')
        if 'Cuba' in x:
            genres.append('Cuba')
        if 'Malaysia' in x:
            genres.append('Malaysia')
        if 'Bulgaria' in x:
            genres.append('Bulgaria')
        if 'Serbia' in x:
            genres.append('Serbia')
        if 'Greece' in x:
            genres.append('Greecee')
        if 'Thailand' in x:
            genres.append('Thailand')
        if 'Cameroon' in x:
            genres.append('Cameroon')
        if 'Colombia' in x:
            genres.append('Colombia')
        if 'Netherlands' in x:
            genres.append('Netherlands')
        if 'Philippines' in x:
            genres.append('Philippines')
        if 'Libyan Arab Jamahiriya' in x:
            genres.append('Libyan Arab Jamahiriya')
        if 'Iceland' in x:
            genres.append('Iceland')
        if 'Soviet Union' in x:
            genres.append('Soviet Union')
        if 'Turkey' in x:
            genres.append('Turkey')
        if 'Singapore' in x:
            genres.append('Singapore')
        if 'Bosnia and Herzegovina' in x:
            genres.append('Bosnia and Herzegovina')
        if 'Czechoslovakia' in x:
            genres.append('Czechoslovakia')
        if 'Martinique' in x:
            genres.append('Martinique')
        if 'Romania' in x:
            genres.append('Romania')
        if 'Armenia' in x:
            genres.append('Armenia')
        if 'Egypt' in x:
            genres.append('Egypt')
        if 'Indonesia' in x:
            genres.append('Indonesia')
        if 'Chile' in x:
            genres.append('Chile')
        if 'Monaco' in x:
            genres.append('Monaco')
        if 'Uruguay' in x:
            genres.append('Uruguay')
        if 'Algeria' in x:
            genres.append('Algeria')
        if 'Lithuania' in x:
            genres.append('Lithuania')
        if 'Palestinian Territory' in x:
            genres.append('Palestinian Territory')
        if 'East Germany' in x:
            genres.append('East Germany')
        if 'Morocco' in x:
            genres.append('Morocco')
        if 'Lebanon' in x:
            genres.append('Lebanon')
        if 'Latvia' in x:
            genres.append('Latvia')
        if 'United Arab Emirates' in x:
            genres.append('United Arab Emirates')
        if 'Slovenia' in x:
            genres.append('Slovenia')
        if 'Cambodia' in x:
            genres.append('Cambodia')
        if 'Botswana' in x:
            genres.append('Botswana')
        if 'Pakistan' in x:
            genres.append('Pakistan')
        if 'Congo' in x:
            genres.append('Congo')
        if 'Tanzania' in x:
            genres.append('Tanzania')
        if 'Bolivia' in x:
            genres.append('Bolivia')
        if 'Kazakhstan' in x:
            genres.append('Kazakhstan')
        if 'Ethiopia' in x:
            genres.append('Ethiopia')
        if 'Qatar' in x:
            genres.append('Qatar')
        if 'Tajikistan' in x:
            genres.append('Tajikistan')
        if 'Belarus' in x:
            genres.append('Belarus')
        if 'Estonia' in x:
            genres.append('Estonia')
        if 'Georgia' in x:
            genres.append('Georgia')
        if 'Mauritania' in x:
            genres.append('Mauritania')
        if 'Burkina Faso' in x:
            genres.append('Burkina Faso')
        if 'Afghanistan' in x:
            genres.append('Afghanistan')
        if 'Croatia' in x:
            genres.append('Croatia')
        if 'Yugoslavia' in x:
            genres.append('Yugoslavia')
        if 'Malta' in x:
            genres.append('Malta')
        if 'Nicaragua' in x:
            genres.append('Nicaragua')
        if 'Ukraine' in x:
            genres.append('Ukraine')
        if 'Venezuela' in x:
            genres.append('Venezuela')
        if 'Iraq' in x:
            genres.append('Iraq')
        if 'Liechtenstein' in x:
            genres.append('Liechtenstein')
        if 'Albania' in x:
            genres.append('Albania')
        if 'Macedonia' in x:
            genres.append('Macedonia')
        if genres:
            return ', '.join(genres)
        else:
            return 'Unknown'

# %%
films['production_countries'] = films['production_countries'].apply(fix_countries)

# %%
#No null values
films[films['production_countries'] == 'Unkown']
# Out:
# Empty DataFrame
# Columns: [genres, id, original_language, original_title, overview, popularity, poster_path, production_companies, production_countries, release_date, runtime, spoken_languages, title, vote_average, vote_count, cast, crew, year, director, director_gender, prod_countries]
# Index: []
#
# [0 rows x 21 columns]

# %% [markdown]
# ## Dropping columns

# %%
films.drop(columns=[ 'release_date', 'poster_path', 'cast', 'crew'], inplace=True)

# %% [markdown]
# ## Exporting to CSV

# %%
films.to_csv('films_clean.csv', index=False)

# %%
films['director'].value_counts()
# Out:
# Werner Herzog               44
# Jean-Luc Godard             40
# Ingmar Bergman              36
# Rainer Werner Fassbinder    30
# Akira Kurosawa              28
#                             ..
# Justin Dix                   1
# James Cameron                1
# John Flynn                   1
# Jem Cohen                    1
# Larry Shaw                   1
# Name: director, Length: 3785, dtype: int64
