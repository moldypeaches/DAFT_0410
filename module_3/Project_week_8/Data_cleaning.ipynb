# %%
import pandas as pd
male = pd.read_csv('movies_clean.csv')

# %% [markdown]
# ##Dropping columns

# %%
male.drop(columns=['runtime','spoken_languages', 'original_title', 'release_date', 'poster_path'], inplace=True)

# %%
male[male['director_gender']== 'female']
# Out:
#                                                  genres      id  \
# 13    [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...    8391
# 18    [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...    4482
# 25    [{'id': 18, 'name': 'Drama'}, {'id': 35, 'name...   11907
# 44    [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...   36834
# 62    [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...   40156
# ...                                                 ...     ...
# 9747  [{'id': 10749, 'name': 'Romance'}, {'id': 18, ...  182981
# 9751  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...   30019
# 9755  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...  366505
# 9763                                                 []  408624
# 9771  [{'id': 10749, 'name': 'Romance'}, {'id': 18, ...   63281
#
#      original_language                                           overview  \
# 13             English  A prudish woman, working on tenure as a litera...
# 18              French  After learning of her husband's infidelities, ...
# 25              German                                 No overview found.
# 44             English  Young, wild poet Arthur Rimbaud and his mentor...
# 62             English  Father Greg Pilkington (Linus Roache) is torn ...
# ...                ...                                                ...
# 9747             Dutch  Naomi, a fifteen year-old Dutch girl from Sout...
# 9751         Norwegian  As young children, half-siblings Axel and Yann...
# 9755           Spanish  Alma’s family has been producing quality olive...
# 9763           English  A sensitive university student unraveling whil...
# 9771           English  У девушки Даши, приехавшей с подругой «покорят...
#
#       popularity                               production_companies  \
# 13      3.302524  [{'name': 'Alliance Communications Corporation...
# 18      2.518051  [{'name': 'Renn Productions', 'id': 82}, {'nam...
# 25      1.015068                                                 []
# 44      4.546552  [{'name': 'Société Française de Production (SF...
# 62      1.881932  [{'name': 'BBC Films', 'id': 288}, {'name': 'P...
# ...          ...                                                ...
# 9747    0.420688  [{'name': 'Canal+', 'id': 5358}, {'name': 'App...
# 9751    1.056898  [{'name': 'Riva Filmproduktion', 'id': 2677}, ...
# 9755    2.541633  [{'name': 'Eurimages', 'id': 850}, {'name': 'F...
# 9763    0.516993  [{'name': 'Studioz IDrream', 'id': 85800}, {'n...
# 9771    0.121844                  [{'name': 'Profit', 'id': 21163}]
#
#                                    production_countries  \
# 13             [{'iso_3166_1': 'CA', 'name': 'Canada'}]
# 18             [{'iso_3166_1': 'FR', 'name': 'France'}]
# 25            [{'iso_3166_1': 'DE', 'name': 'Germany'}]
# 44    [{'iso_3166_1': 'FR', 'name': 'France'}, {'iso...
# 62     [{'iso_3166_1': 'GB', 'name': 'United Kingdom'}]
# ...                                                 ...
# 9747  [{'iso_3166_1': 'NL', 'name': 'Netherlands'}, ...
# 9751           [{'iso_3166_1': 'NO', 'name': 'Norway'}]
# 9755  [{'iso_3166_1': 'DE', 'name': 'Germany'}, {'is...
# 9763            [{'iso_3166_1': 'IN', 'name': 'India'}]
# 9771           [{'iso_3166_1': 'RU', 'name': 'Russia'}]
#
#                       title  vote_average  vote_count  \
# 13    When Night Is Falling           5.9        10.0
# 18             French Twist           6.0        43.0
# 25          Nobody Loves Me           5.1         5.0
# 44            Total Eclipse           6.5       112.0
# 62                   Priest           6.4        32.0
# ...                     ...           ...         ...
# 9747              Nude Area           5.0         2.0
# 9751               Upperdog           6.9         5.0
# 9755         The Olive Tree           6.5        38.0
# 9763    A Death in the Gunj           7.0         5.0
# 9771            Pro Lyuboff           4.0         3.0
#
#                                                    cast  \
# 13    [{'cast_id': 1, 'character': 'Camille Baker', ...
# 18    [{'cast_id': 4, 'character': 'Loli', 'credit_i...
# 25    [{'cast_id': 1, 'character': 'Fanny Fink', 'cr...
# 44    [{'cast_id': 1, 'character': 'Arthur Rimbaud',...
# 62    [{'cast_id': 2, 'character': 'Father Greg Pilk...
# ...                                                 ...
# 9747  [{'cast_id': 2, 'character': 'Naomi', 'credit_...
# 9751  [{'cast_id': 3, 'character': 'Axel', 'credit_i...
# 9755  [{'cast_id': 2, 'character': 'Alcachofas', 'cr...
# 9763  [{'cast_id': 1, 'character': 'Shyamlal Chatter...
# 9771  [{'cast_id': 1001, 'character': 'Vlad', 'credi...
#
#                                                    crew  year  \
# 13    [{'credit_id': '52fe44a4c3a36847f80a1e53', 'de...  1995
# 18    [{'credit_id': '52fe43c5c3a36847f806e5f3', 'de...  1995
# 25    [{'credit_id': '52fe449f9251416c7503b371', 'de...  1994
# 44    [{'credit_id': '52fe460f9251416c91047b0f', 'de...  1995
# 62    [{'credit_id': '52fe4583c3a36847f80cb96b', 'de...  1994
# ...                                                 ...   ...
# 9747  [{'credit_id': '52fe4c929251416c7511ea9d', 'de...  2014
# 9751  [{'credit_id': '571e27699251411ca700149b', 'de...  2009
# 9755  [{'credit_id': '572af90ec3a3685429000988', 'de...  2016
# 9763  [{'credit_id': '58877d529251415ff70053e7', 'de...  2016
# 9771  [{'credit_id': '52fe46a3c3a368484e09b9fd', 'de...  2010
#
#                 director director_gender
# 13       Patricia Rozema          female
# 18       Josiane Balasko          female
# 25          Doris Dörrie          female
# 44     Agnieszka Holland          female
# 62          Antonia Bird          female
# ...                  ...             ...
# 9747    Urszula Antoniak          female
# 9751        Sara Johnsen          female
# 9755       Icíar Bollaín          female
# 9763  Konkona Sen Sharma          female
# 9771      Olga Subbotina          female
#
# [681 rows x 15 columns]

# %%
#No null values 
male.isna().sum()
# Out:
# genres                  0
# id                      0
# original_language       0
# overview                0
# popularity              0
# production_companies    0
# production_countries    0
# title                   0
# vote_average            0
# vote_count              0
# cast                    0
# crew                    0
# year                    0
# director                0
# director_gender         0
# dtype: int64

# %%
male[male['director_gender']== 'female']
# Out:
#                                                  genres      id  \
# 13    [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...    8391
# 18    [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...    4482
# 25    [{'id': 18, 'name': 'Drama'}, {'id': 35, 'name...   11907
# 44    [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...   36834
# 62    [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...   40156
# ...                                                 ...     ...
# 9747  [{'id': 10749, 'name': 'Romance'}, {'id': 18, ...  182981
# 9751  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...   30019
# 9755  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...  366505
# 9763                                                 []  408624
# 9771  [{'id': 10749, 'name': 'Romance'}, {'id': 18, ...   63281
#
#      original_language                                           overview  \
# 13             English  A prudish woman, working on tenure as a litera...
# 18              French  After learning of her husband's infidelities, ...
# 25              German                                 No overview found.
# 44             English  Young, wild poet Arthur Rimbaud and his mentor...
# 62             English  Father Greg Pilkington (Linus Roache) is torn ...
# ...                ...                                                ...
# 9747             Dutch  Naomi, a fifteen year-old Dutch girl from Sout...
# 9751         Norwegian  As young children, half-siblings Axel and Yann...
# 9755           Spanish  Alma’s family has been producing quality olive...
# 9763           English  A sensitive university student unraveling whil...
# 9771           English  У девушки Даши, приехавшей с подругой «покорят...
#
#       popularity                               production_companies  \
# 13      3.302524  [{'name': 'Alliance Communications Corporation...
# 18      2.518051  [{'name': 'Renn Productions', 'id': 82}, {'nam...
# 25      1.015068                                                 []
# 44      4.546552  [{'name': 'Société Française de Production (SF...
# 62      1.881932  [{'name': 'BBC Films', 'id': 288}, {'name': 'P...
# ...          ...                                                ...
# 9747    0.420688  [{'name': 'Canal+', 'id': 5358}, {'name': 'App...
# 9751    1.056898  [{'name': 'Riva Filmproduktion', 'id': 2677}, ...
# 9755    2.541633  [{'name': 'Eurimages', 'id': 850}, {'name': 'F...
# 9763    0.516993  [{'name': 'Studioz IDrream', 'id': 85800}, {'n...
# 9771    0.121844                  [{'name': 'Profit', 'id': 21163}]
#
#                                    production_countries  \
# 13             [{'iso_3166_1': 'CA', 'name': 'Canada'}]
# 18             [{'iso_3166_1': 'FR', 'name': 'France'}]
# 25            [{'iso_3166_1': 'DE', 'name': 'Germany'}]
# 44    [{'iso_3166_1': 'FR', 'name': 'France'}, {'iso...
# 62     [{'iso_3166_1': 'GB', 'name': 'United Kingdom'}]
# ...                                                 ...
# 9747  [{'iso_3166_1': 'NL', 'name': 'Netherlands'}, ...
# 9751           [{'iso_3166_1': 'NO', 'name': 'Norway'}]
# 9755  [{'iso_3166_1': 'DE', 'name': 'Germany'}, {'is...
# 9763            [{'iso_3166_1': 'IN', 'name': 'India'}]
# 9771           [{'iso_3166_1': 'RU', 'name': 'Russia'}]
#
#                       title  vote_average  vote_count  \
# 13    When Night Is Falling           5.9        10.0
# 18             French Twist           6.0        43.0
# 25          Nobody Loves Me           5.1         5.0
# 44            Total Eclipse           6.5       112.0
# 62                   Priest           6.4        32.0
# ...                     ...           ...         ...
# 9747              Nude Area           5.0         2.0
# 9751               Upperdog           6.9         5.0
# 9755         The Olive Tree           6.5        38.0
# 9763    A Death in the Gunj           7.0         5.0
# 9771            Pro Lyuboff           4.0         3.0
#
#                                                    cast  \
# 13    [{'cast_id': 1, 'character': 'Camille Baker', ...
# 18    [{'cast_id': 4, 'character': 'Loli', 'credit_i...
# 25    [{'cast_id': 1, 'character': 'Fanny Fink', 'cr...
# 44    [{'cast_id': 1, 'character': 'Arthur Rimbaud',...
# 62    [{'cast_id': 2, 'character': 'Father Greg Pilk...
# ...                                                 ...
# 9747  [{'cast_id': 2, 'character': 'Naomi', 'credit_...
# 9751  [{'cast_id': 3, 'character': 'Axel', 'credit_i...
# 9755  [{'cast_id': 2, 'character': 'Alcachofas', 'cr...
# 9763  [{'cast_id': 1, 'character': 'Shyamlal Chatter...
# 9771  [{'cast_id': 1001, 'character': 'Vlad', 'credi...
#
#                                                    crew  year  \
# 13    [{'credit_id': '52fe44a4c3a36847f80a1e53', 'de...  1995
# 18    [{'credit_id': '52fe43c5c3a36847f806e5f3', 'de...  1995
# 25    [{'credit_id': '52fe449f9251416c7503b371', 'de...  1994
# 44    [{'credit_id': '52fe460f9251416c91047b0f', 'de...  1995
# 62    [{'credit_id': '52fe4583c3a36847f80cb96b', 'de...  1994
# ...                                                 ...   ...
# 9747  [{'credit_id': '52fe4c929251416c7511ea9d', 'de...  2014
# 9751  [{'credit_id': '571e27699251411ca700149b', 'de...  2009
# 9755  [{'credit_id': '572af90ec3a3685429000988', 'de...  2016
# 9763  [{'credit_id': '58877d529251415ff70053e7', 'de...  2016
# 9771  [{'credit_id': '52fe46a3c3a368484e09b9fd', 'de...  2010
#
#                 director director_gender
# 13       Patricia Rozema          female
# 18       Josiane Balasko          female
# 25          Doris Dörrie          female
# 44     Agnieszka Holland          female
# 62          Antonia Bird          female
# ...                  ...             ...
# 9747    Urszula Antoniak          female
# 9751        Sara Johnsen          female
# 9755       Icíar Bollaín          female
# 9763  Konkona Sen Sharma          female
# 9771      Olga Subbotina          female
#
# [681 rows x 15 columns]

# %%
male.drop_duplicates(subset='id', inplace=True)
male['id'].value_counts()
# Out:
# 11860     1
# 167956    1
# 68744     1
# 44023     1
# 84508     1
#          ..
# 43389     1
# 14298     1
# 9381      1
# 16182     1
# 30840     1
# Name: id, Length: 9769, dtype: int64

# %%
male['vote_average'].sort_values()
# Out:
# 6057     0.0
# 3785     0.0
# 8053     0.0
# 9301     0.0
# 3081     0.0
#         ...
# 8434    10.0
# 5357    10.0
# 4987    10.0
# 3960    10.0
# 7827    10.0
# Name: vote_average, Length: 9769, dtype: float64

# %%
# I decided to drop this column, as well as "vote_count" because I saw that "Call Me by Your Name", a very popular film, had a vote average 0. I will keep the column "popularity" which is more reliable, with a value of 4.300874.
male[male['vote_average'] == 0.0]
#male.drop(columns=['vote_average','vote_count'], inplace=True)
# Out:
#                                                  genres      id  \
# 3081  [{'id': 18, 'name': 'Drama'}, {'id': 10770, 'n...  111744
# 3785                     [{'id': 35, 'name': 'Comedy'}]  252407
# 4322  [{'id': 18, 'name': 'Drama'}, {'id': 14, 'name...   63702
# 6057                      [{'id': 18, 'name': 'Drama'}]   56178
# 6405  [{'id': 18, 'name': 'Drama'}, {'id': 36, 'name...   66963
# 6772                  [{'id': 12, 'name': 'Adventure'}]   95029
# 7141  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...  212934
# 7426  [{'id': 10770, 'name': 'TV Movie'}, {'id': 37,...   86543
# 8053                      [{'id': 18, 'name': 'Drama'}]  299143
# 9253  [{'id': 10749, 'name': 'Romance'}, {'id': 18, ...  398818
# 9301                      [{'id': 18, 'name': 'Drama'}]  429732
#
#      original_language                                           overview  \
# 3081           English  True story of boxers Joe Louis and Max Schmeli...
# 3785           English  A man's enthusiastic penis starts talking to h...
# 4322            French  Two women love the same man in a world of few ...
# 6057            French  Lucienne, typist and gorgeous bathing beauty, ...
# 6405            French  French silent film pioneer Abel Gance directs ...
# 6772           English  Years after fleeing his ancestral home with hi...
# 7141           English  An inside look at the ABC sitcom which turned ...
# 7426           English  Four orphan boys running from the law in New Y...
# 8053           Italian  Episodic film about the lives of a few people ...
# 9253           English  Elio Perlman is spending the summer with his f...
# 9301            French  Toma and Ana meet as students in the literatur...
#
#       popularity                               production_companies  \
# 3081    1.669115                                                 []
# 3785    0.645652    [{'name': 'Neue Constantin Film', 'id': 13096}]
# 4322    0.157182  [{'name': 'Les Productions Fox Europa', 'id': ...
# 6057    0.444066                                                 []
# 6405    0.142167                                                 []
# 6772    0.177689   [{'name': 'New World Productions', 'id': 45641}]
# 7141    0.088172  [{'name': 'NBC Studios', 'id': 7928}, {'name':...
# 7426    0.625766  [{'name': 'Hallmark Hall of Fame Productions',...
# 8053    0.040130  [{'name': 'Orbis Film', 'id': 36389}, {'name':...
# 9253    4.300874  [{'name': 'Sony Pictures Classics', 'id': 58},...
# 9301    2.160256  [{'name': 'Sophie Dulac Productions', 'id': 18...
#
#                                    production_countries  \
# 3081  [{'iso_3166_1': 'US', 'name': 'United States o...
# 3785          [{'iso_3166_1': 'DE', 'name': 'Germany'}]
# 4322           [{'iso_3166_1': 'FR', 'name': 'France'}]
# 6057           [{'iso_3166_1': 'FR', 'name': 'France'}]
# 6405           [{'iso_3166_1': 'FR', 'name': 'France'}]
# 6772   [{'iso_3166_1': 'GB', 'name': 'United Kingdom'}]
# 7141           [{'iso_3166_1': 'CA', 'name': 'Canada'}]
# 7426  [{'iso_3166_1': 'US', 'name': 'United States o...
# 8053            [{'iso_3166_1': 'IT', 'name': 'Italy'}]
# 9253  [{'iso_3166_1': 'BR', 'name': 'Brazil'}, {'iso...
# 9301  [{'iso_3166_1': 'RO', 'name': 'Romania'}, {'is...
#
#                                                   title  vote_average  \
# 3081                                        Joe and Max           0.0
# 3785                                         Me and Him           0.0
# 4322                                             Liliom           0.0
# 6057                                       Beauty Prize           0.0
# 6405                                    Lucrezia Borgia           0.0
# 6772                                  The Hellfire Club           0.0
# 7141  Behind the Camera: The Unauthorized Story of '...           0.0
# 7426                                          Rose Hill           0.0
# 8053                                 The Gate of Heaven           0.0
# 9253                               Call Me by Your Name           0.0
# 9301                                       Ana, My Love           0.0
#
#       vote_count                                               cast  \
# 3081         1.0  [{'cast_id': 1001, 'character': 'Joe Louis', '...
# 3785         1.0  [{'cast_id': 1, 'character': 'Bert Uttanzi', '...
# 4322         2.0  [{'cast_id': 4, 'character': 'Liliom Zadowski'...
# 6057         1.0  [{'cast_id': 1001, 'character': 'Lucienne', 'c...
# 6405         2.0  [{'cast_id': 2, 'character': 'Lucrezia Borgia'...
# 6772         1.0  [{'cast_id': 4, 'character': 'Jason', 'credit_...
# 7141         1.0  [{'cast_id': 2, 'character': 'Robin Williams',...
# 7426         1.0  [{'cast_id': 2, 'character': 'Mary Rose Claybo...
# 8053         1.0  [{'cast_id': 0, 'character': 'The nurse', 'cre...
# 9253        18.0  [{'cast_id': 4, 'character': 'Elio Perlman', '...
# 9301         3.0  [{'cast_id': 5, 'character': 'Toma', 'credit_i...
#
#                                                    crew  year  \
# 3081  [{'credit_id': '593caed79251410587015f8b', 'de...  2002
# 3785  [{'credit_id': '5892039a9251412dc8008a19', 'de...  1988
# 4322  [{'credit_id': '52fe46b7c3a368484e09ffc1', 'de...  1934
# 6057  [{'credit_id': '52fe48f3c3a36847f8181d0b', 'de...  1930
# 6405  [{'credit_id': '52fe4752c3a368484e0c089b', 'de...  1935
# 6772  [{'credit_id': '54cf9dbc9251415cb8007196', 'de...  1961
# 7141  [{'credit_id': '52fe4dbac3a368484e1f9ab9', 'de...  2005
# 7426  [{'credit_id': '56d071a6c3a3681e44007122', 'de...  1997
# 8053  [{'credit_id': '5812de86c3a3687aa0020f68', 'de...  1945
# 9253  [{'credit_id': '5742ea0ec3a3686c8c001a6e', 'de...  2017
# 9301  [{'credit_id': '589fd3dfc3a3684e7b000278', 'de...  2017
#
#                 director director_gender
# 3081         Steve James            male
# 3785        Doris Dörrie          female
# 4322          Fritz Lang            male
# 6057      Augusto Genina            male
# 6405          Abel Gance            male
# 6772     Robert S. Baker            male
# 7141      Neill Fearnley            male
# 7426    Christopher Cain            male
# 8053    Vittorio De Sica            male
# 9253     Luca Guadagnino            male
# 9301  Călin Peter Netzer            male

# %%
#I checked the relevance of "popularity" column by checking the movies with lowest and highest rates.
male['popularity'].sort_values()
male['popularity'].sort_values(ascending=False)
male.loc[9462]
# Out:
# genres                  [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...
# id                                                                 339403
# original_language                                                 English
# overview                After being coerced into working for a crime b...
# popularity                                                     228.032744
# production_companies    [{'name': 'Big Talk Productions', 'id': 443}, ...
# production_countries    [{'iso_3166_1': 'GB', 'name': 'United Kingdom'...
# title                                                         Baby Driver
# vote_average                                                          7.2
# vote_count                                                         2083.0
# cast                    [{'cast_id': 9, 'character': 'Baby', 'credit_i...
# crew                    [{'credit_id': '55c58c009251417a21000e5d', 'de...
# year                                                                 2017
# director                                                     Edgar Wright
# director_gender                                                      male
# Name: 9462, dtype: object

# %%
#new_list.isna().sum()

# %% [markdown]
# ##Cleaning the columns

# %%
def fix_genres_names(x):
    x = str(x)
    genres = []
    
    if 'Comedy' in x:
        genres.append('Comedy')
    if 'Action' in x:
        genres.append('Action')
    if 'Drama' in x:
        genres.append('Drama')
    if 'Crime' in x:
        genres.append('Crime')
    if 'Romance' in x:
        genres.append('Romance')
    if 'Adventure' in x:
        genres.append('Adventure')
    if 'Thriller' in x:
        genres.append('Thriller')
    if 'Fantasy' in x:
        genres.append('Fantasy')
    if 'Science Fiction' in x:
        genres.append('Science Fiction')
    if 'History' in x:
        genres.append('History')
    if 'War' in x:
        genres.append('War')
    if 'Foreign' in x:
        genres.append('Foreign')
    if 'Mystery' in x:
        genres.append('Mystery')
    if 'Family' in x:
        genres.append('Family')
    if 'Documentary' in x:
        genres.append('Documentary')
    if 'Horror' in x:
        genres.append('Horror')
    if 'Animation' in x:
        genres.append('Animation')
    if 'Western' in x:
        genres.append('Western')
    if 'Music' in x:
        genres.append('Music')
    if 'TV Movie' in x:
        genres.append('TV Movie')
    
    if genres:
        return ', '.join(genres)
    else:
        return 'Unknown'

# %%
male['genres'] = male['genres'].apply(fix_genres_names)

# %%
#Fix production countries
male['prod_countries'] = male['production_countries'].str.extract(r"'name': '([^']*)'")
male['prod_countries'].unique()
# Out:
# array(['Germany', 'France', 'United Kingdom', 'Italy', 'China',
#        'United States of America', 'Canada', 'Belgium', 'Iran',
#        'Hong Kong', 'Dominican Republic', 'Ireland', 'Taiwan',
#        'New Zealand', 'Mexico', 'Japan', 'Peru', 'Australia',
#        'South Africa', 'Denmark', 'Finland', 'Spain', 'South Korea',
#        'Sweden', 'Argentina', 'Hungary', 'Austria', 'Czech Republic',
#        'Vietnam', 'Switzerland', 'Trinidad and Tobago', 'Portugal',
#        'Russia', 'India', 'Brazil', 'Norway', 'Aruba', 'Israel',
#        'Luxembourg', 'Poland', 'Cuba', 'Malaysia', 'Bulgaria', 'Serbia',
#        'Greece', 'Thailand', 'Cameroon', 'Colombia', 'Netherlands',
#        'Philippines', 'Libyan Arab Jamahiriya', 'Iceland', 'Soviet Union',
#        'Turkey', 'Singapore', 'Bosnia and Herzegovina', 'Czechoslovakia',
#        'Martinique', 'Romania', 'Armenia', 'Egypt', 'Indonesia', 'Chile',
#        'Monaco', 'Uruguay', 'Algeria', 'Lithuania',
#        'Palestinian Territory', 'East Germany', 'Morocco', 'Lebanon',
#        'Latvia', 'United Arab Emirates', 'Slovenia', 'Cambodia',
#        'Botswana', 'Pakistan', 'Congo', 'Tanzania', 'Bolivia',
#        'Kazakhstan', 'Ethiopia', 'Qatar', 'Tajikistan', 'Belarus',
#        'Estonia', 'Georgia', 'Mauritania', 'Burkina Faso', 'Afghanistan',
#        'Croatia', 'Yugoslavia', 'Malta', 'Nicaragua', 'Ukraine',
#        'Venezuela', 'Iraq', 'Liechtenstein', 'Albania', 'Macedonia'],
#       dtype=object)

# %%
    def fix_countries(x):
        x = str(x)
        genres = []
    
        if 'Germany' in x:
            genres.append('Germany')
        if 'France' in x:
            genres.append('France')
        if 'United Kingdom' in x:
            genres.append('United Kingdom')
        if 'Italy' in x:
            genres.append('Italy')
        if 'China' in x:
            genres.append('China')
        if 'United States of America' in x:
            genres.append('United States of America')
        if 'Canada' in x:
            genres.append('Canada')
        if 'Belgium' in x:
            genres.append('Belgium')
        if 'Iran' in x:
            genres.append('Iran')
        if 'Hong Kong' in x:
            genres.append('Hong Kong')
        if 'Dominican Republic' in x:
            genres.append('Dominican Republic')
        if 'Ireland' in x:
            genres.append('Ireland')
        if 'Taiwan' in x:
            genres.append('Taiwan')
        if 'New Zealand' in x:
            genres.append('New Zealand')
        if 'Mexico' in x:
            genres.append('Mexico')
        if 'Japan' in x:
            genres.append('Japan')
        if 'Peru' in x:
            genres.append('Peru')
        if 'Australia' in x:
            genres.append('Australia')
        if 'South Africa' in x:
            genres.append('South Africa')
        if 'Denmark' in x:
            genres.append('Denmark')
        if 'Finland' in x:
            genres.append('Finland')
        if 'Spain' in x:
            genres.append('Spain')
        if 'Sweden' in x:
            genres.append('Sweden')
        if 'South Korea' in x:
            genres.append('South Korea')
        if 'Sweden' in x:
            genres.append('Sweden')
        if 'Argentina' in x:
            genres.append('Argentina')
        if 'Hungary' in x:
            genres.append('Hungary')
        if 'Austria' in x:
            genres.append('Austria')
        if 'Czech Republic' in x:
            genres.append('Czech Republic')
        if 'Vietnam' in x:
            genres.append('Vietnam')
        if 'Switzerland' in x:
            genres.append('Switzerland')
        if 'Trinidad and Tobago' in x:
            genres.append('Trinidad and Tobago')
        if 'Portugal' in x:
            genres.append('Portugal')
        if 'Russia' in x:
            genres.append('Russia')
        if 'India' in x:
            genres.append('India')
        if 'Brazil' in x:
            genres.append('Brazil')
        if 'Norway' in x:
            genres.append('Norway')
        if 'Aruba' in x:
            genres.append('Aruba')
        if 'Israel' in x:
            genres.append('Israel')
        if 'Luxembourg' in x:
            genres.append('Luxembourg')
        if 'Poland' in x:
            genres.append('Poland')
        if 'Cuba' in x:
            genres.append('Cuba')
        if 'Malaysia' in x:
            genres.append('Malaysia')
        if 'Bulgaria' in x:
            genres.append('Bulgaria')
        if 'Serbia' in x:
            genres.append('Serbia')
        if 'Greece' in x:
            genres.append('Greecee')
        if 'Thailand' in x:
            genres.append('Thailand')
        if 'Cameroon' in x:
            genres.append('Cameroon')
        if 'Colombia' in x:
            genres.append('Colombia')
        if 'Netherlands' in x:
            genres.append('Netherlands')
        if 'Philippines' in x:
            genres.append('Philippines')
        if 'Libyan Arab Jamahiriya' in x:
            genres.append('Libyan Arab Jamahiriya')
        if 'Iceland' in x:
            genres.append('Iceland')
        if 'Soviet Union' in x:
            genres.append('Soviet Union')
        if 'Turkey' in x:
            genres.append('Turkey')
        if 'Singapore' in x:
            genres.append('Singapore')
        if 'Bosnia and Herzegovina' in x:
            genres.append('Bosnia and Herzegovina')
        if 'Czechoslovakia' in x:
            genres.append('Czechoslovakia')
        if 'Martinique' in x:
            genres.append('Martinique')
        if 'Romania' in x:
            genres.append('Romania')
        if 'Armenia' in x:
            genres.append('Armenia')
        if 'Egypt' in x:
            genres.append('Egypt')
        if 'Indonesia' in x:
            genres.append('Indonesia')
        if 'Chile' in x:
            genres.append('Chile')
        if 'Monaco' in x:
            genres.append('Monaco')
        if 'Uruguay' in x:
            genres.append('Uruguay')
        if 'Algeria' in x:
            genres.append('Algeria')
        if 'Lithuania' in x:
            genres.append('Lithuania')
        if 'Palestinian Territory' in x:
            genres.append('Palestinian Territory')
        if 'East Germany' in x:
            genres.append('East Germany')
        if 'Morocco' in x:
            genres.append('Morocco')
        if 'Lebanon' in x:
            genres.append('Lebanon')
        if 'Latvia' in x:
            genres.append('Latvia')
        if 'United Arab Emirates' in x:
            genres.append('United Arab Emirates')
        if 'Slovenia' in x:
            genres.append('Slovenia')
        if 'Cambodia' in x:
            genres.append('Cambodia')
        if 'Botswana' in x:
            genres.append('Botswana')
        if 'Pakistan' in x:
            genres.append('Pakistan')
        if 'Congo' in x:
            genres.append('Congo')
        if 'Tanzania' in x:
            genres.append('Tanzania')
        if 'Bolivia' in x:
            genres.append('Bolivia')
        if 'Kazakhstan' in x:
            genres.append('Kazakhstan')
        if 'Ethiopia' in x:
            genres.append('Ethiopia')
        if 'Qatar' in x:
            genres.append('Qatar')
        if 'Tajikistan' in x:
            genres.append('Tajikistan')
        if 'Belarus' in x:
            genres.append('Belarus')
        if 'Estonia' in x:
            genres.append('Estonia')
        if 'Georgia' in x:
            genres.append('Georgia')
        if 'Mauritania' in x:
            genres.append('Mauritania')
        if 'Burkina Faso' in x:
            genres.append('Burkina Faso')
        if 'Afghanistan' in x:
            genres.append('Afghanistan')
        if 'Croatia' in x:
            genres.append('Croatia')
        if 'Yugoslavia' in x:
            genres.append('Yugoslavia')
        if 'Malta' in x:
            genres.append('Malta')
        if 'Nicaragua' in x:
            genres.append('Nicaragua')
        if 'Ukraine' in x:
            genres.append('Ukraine')
        if 'Venezuela' in x:
            genres.append('Venezuela')
        if 'Iraq' in x:
            genres.append('Iraq')
        if 'Liechtenstein' in x:
            genres.append('Liechtenstein')
        if 'Albania' in x:
            genres.append('Albania')
        if 'Macedonia' in x:
            genres.append('Macedonia')
        if genres:
            return ', '.join(genres)
        else:
            return 'Unknown'

# %%
male['production_countries'] = male['production_countries'].apply(fix_countries)

# %%
male[male['production_countries'] == 'Macedonia']
# Out:
#      genres      id original_language  \
# 9718  Drama  108827        Macedonian
#
#                                                overview  popularity  \
# 9718  As Macedonia faces its difficult transition, a...    0.211851
#
#                         production_companies production_countries   title  \
# 9718  [{'name': 'Small Moves', 'id': 63637}]            Macedonia  Mirage
#
#       vote_average  vote_count  \
# 9718           7.0         2.0
#
#                                                    cast  \
# 9718  [{'cast_id': 4, 'character': "Lazo / Marko's F...
#
#                                                    crew  year  \
# 9718  [{'credit_id': '52fe4aa4c3a36847f81d9e39', 'de...  2004
#
#                 director director_gender prod_countries
# 9718  Svetozar Ristovski            male      Macedonia

# %%
female = male[male['director_gender'] == 'female']
male_ = male[male['director_gender'] == 'male']

# %%
final_male = male_ 
final_female = female
final_male.drop(columns= ['crew','cast', 'director_gender','production_companies','prod_countries'], inplace=True)
final_female.drop(columns= ['crew','cast', 'director_gender' , 'production_companies', 'prod_countries'], inplace=True)
# Out:
# /var/folders/_s/5ccjvt852hv4ddn7j5mrvy1m0000gn/T/ipykernel_64810/2834992795.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_male.drop(columns= ['crew','cast', 'director_gender','production_companies','prod_countries'], inplace=True)
# /var/folders/_s/5ccjvt852hv4ddn7j5mrvy1m0000gn/T/ipykernel_64810/2834992795.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_female.drop(columns= ['crew','cast', 'director_gender' , 'production_companies', 'prod_countries'], inplace=True)

# %%
final_male
# Out:
#                                  genres      id original_language  \
# 0                       Comedy, Romance   11860           English
# 1                        Comedy, Horror   12110           English
# 2                     Action, Adventure    1408           English
# 3                          Drama, Crime     524           English
# 4                        Drama, Romance    4584           English
# ...                                 ...     ...               ...
# 9773   Drama, Thriller, Mystery, Horror  365432           English
# 9774  Action, Thriller, Mystery, Horror   45527           English
# 9775            Drama, Family, TV Movie   39562           English
# 9776                             Comedy   14008           English
# 9777             Action, Drama, Romance   30840           English
#
#                                                overview  popularity  \
# 0     An ugly duckling having undergone a remarkable...    6.677277
# 1     When a lawyer shows up at the vampire's doorst...    5.430331
# 2     Morgan Adams and her slave, William Shaw, are ...    7.284477
# 3     The life of the gambling paradise – Las Vegas ...   10.137389
# 4     Rich Mr. Dashwood dies, leaving his second wif...   10.673167
# ...                                                 ...         ...
# 9773  The Sublet is a suspense driven psychological ...    1.339355
# 9774  A stranger named Silas flees from a devastatin...    1.270832
# 9775  Pretty, popular, and slim high-schooler Aly Sc...    0.767762
# 9776  Hyperactive teenager Kelly is enrolled into a ...    4.392389
# 9777  Yet another version of the classic epic, with ...    5.683753
#
#                                    production_countries  \
# 0                     Germany, United States of America
# 1                      France, United States of America
# 2      Germany, France, Italy, United States of America
# 3                      France, United States of America
# 4              United Kingdom, United States of America
# ...                                                 ...
# 9773                                             Canada
# 9774                                    Germany, Canada
# 9775                                             Canada
# 9776                   United States of America, Canada
# 9777  Germany, United Kingdom, United States of Amer...
#
#                             title  vote_average  vote_count  year  \
# 0                         Sabrina           6.2       141.0  1995
# 1     Dracula: Dead and Loving It           5.7       210.0  1995
# 2                Cutthroat Island           5.7       137.0  1995
# 3                          Casino           7.8      1343.0  1995
# 4           Sense and Sensibility           7.2       364.0  1995
# ...                           ...           ...         ...   ...
# 9773                   The Sublet           6.5         4.0  2015
# 9774              The Final Storm           3.7        11.0  2010
# 9775            To Be Fat Like Me           5.0        12.0  2007
# 9776                  Cadet Kelly           5.2       145.0  2002
# 9777                   Robin Hood           5.7        26.0  1991
#
#              director
# 0      Sydney Pollack
# 1          Mel Brooks
# 2        Renny Harlin
# 3     Martin Scorsese
# 4             Ang Lee
# ...               ...
# 9773     John Ainslie
# 9774         Uwe Boll
# 9775     Douglas Barr
# 9776       Larry Shaw
# 9777       John Irvin
#
# [9088 rows x 11 columns]

# %%
final_female
# Out:
#                      genres      id original_language  \
# 13           Drama, Romance    8391           English
# 18          Comedy, Romance    4482            French
# 25    Comedy, Drama, Family   11907            German
# 44           Drama, Romance   36834           English
# 62           Drama, Romance   40156           English
# ...                     ...     ...               ...
# 9747         Drama, Romance  182981             Dutch
# 9751          Comedy, Drama   30019         Norwegian
# 9755          Comedy, Drama  366505           Spanish
# 9763                Unknown  408624           English
# 9771         Drama, Romance   63281           English
#
#                                                overview  popularity  \
# 13    A prudish woman, working on tenure as a litera...    3.302524
# 18    After learning of her husband's infidelities, ...    2.518051
# 25                                   No overview found.    1.015068
# 44    Young, wild poet Arthur Rimbaud and his mentor...    4.546552
# 62    Father Greg Pilkington (Linus Roache) is torn ...    1.881932
# ...                                                 ...         ...
# 9747  Naomi, a fifteen year-old Dutch girl from Sout...    0.420688
# 9751  As young children, half-siblings Axel and Yann...    1.056898
# 9755  Alma’s family has been producing quality olive...    2.541633
# 9763  A sensitive university student unraveling whil...    0.516993
# 9771  У девушки Даши, приехавшей с подругой «покорят...    0.121844
#
#                  production_countries                  title  vote_average  \
# 13                             Canada  When Night Is Falling           5.9
# 18                             France           French Twist           6.0
# 25                            Germany        Nobody Loves Me           5.1
# 44    France, United Kingdom, Belgium          Total Eclipse           6.5
# 62                     United Kingdom                 Priest           6.4
# ...                               ...                    ...           ...
# 9747              Poland, Netherlands              Nude Area           5.0
# 9751                           Norway               Upperdog           6.9
# 9755                   Germany, Spain         The Olive Tree           6.5
# 9763                            India    A Death in the Gunj           7.0
# 9771                           Russia            Pro Lyuboff           4.0
#
#       vote_count  year            director
# 13          10.0  1995     Patricia Rozema
# 18          43.0  1995     Josiane Balasko
# 25           5.0  1994        Doris Dörrie
# 44         112.0  1995   Agnieszka Holland
# 62          32.0  1994        Antonia Bird
# ...          ...   ...                 ...
# 9747         2.0  2014    Urszula Antoniak
# 9751         5.0  2009        Sara Johnsen
# 9755        38.0  2016       Icíar Bollaín
# 9763         5.0  2016  Konkona Sen Sharma
# 9771         3.0  2010      Olga Subbotina
#
# [681 rows x 11 columns]

# %%
final_male.to_csv('male_directed_clean.csv', index=False)

# %%
final_female.to_csv('female_directed_clean.csv', index=False)

# %%
#import pymysql.cursors
#from sqlalchemy import create_engine
#from sqlalchemy import text
#
#
#import getpass
#
#sql_pass = getpass.getpass()
#
#
#connection_string = 'mysql+pymysql://root:' + sql_pass + '@localhost:3306/sdi'
#engine = create_engine(connection_string)
#

# %%
#final_female.to_sql('final_female', engine, 'sdi', if_exists='replace', index=False)

# %%
#final_male.to_sql('final_male', engine, 'sdi', if_exists='replace', index=False)

# %%
male.to_csv('male_clean.csv', index=False)
