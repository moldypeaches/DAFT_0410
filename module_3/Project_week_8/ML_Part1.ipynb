# %%
import pandas as pd
import numpy as np
from scipy.sparse import csr_matrix
import seaborn
from sklearn.decomposition import TruncatedSVD
from sklearn.neighbors import NearestNeighbors

female_directed = pd.read_csv('female_directed_clean.csv')
male_directed = pd.read_csv('male_directed_clean.csv')

# %%
female_directed.drop(columns=['Unnamed: 0', 'ID',], inplace=True)
male_directed.drop(columns=['Unnamed: 0', 'ID', 'director_gender'], inplace=True)

# %%
female_directed[female_directed['vote_average'] == 0].sum
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.sum of                                                   title  \
# 150                                     Men of Tomorrow
# 309                                              Barbie
# 377   Vagabond: Remembrances, Interviews, Notes and ...
# 396                                           Incognito
# 470                                   Flights and Falls
# ...                                                 ...
# 4701                                    Next Door: Fear
# 4703                                           Gagaland
# 4712       Cynthia Erivo: Legendary Voices at the Proms
# 4719                           Thank You and Good Night
# 4722                          Here the Seats Are Vacant
#
#                          genres  releasedate  vote_count  vote_average  \
# 150                       Drama         1932         0.0           0.0
# 309                      Comedy         2023         0.0           0.0
# ...

# %%
male_directed[male_directed['vote_average'] == 0]
# Out:
#                        genres  \
# 3081          Drama, TV Movie
# 3785                   Comedy
# 4322           Drama, Fantasy
# 6057                    Drama
# 6405  Drama, Romance, History
# 6772                Adventure
# 7141            Comedy, Drama
# 7426        Western, TV Movie
# 8053                    Drama
# 9253           Drama, Romance
# 9301                    Drama
#
#                                                   title  vote_average  \
# 3081                                        Joe and Max           0.0
# 3785                                         Me and Him           0.0
# 4322                                             Liliom           0.0
# 6057                                       Beauty Prize           0.0
# 6405                                    Lucrezia Borgia           0.0
# 6772                                  The Hellfire Club           0.0
# 7141  Behind the Camera: The Unauthorized Story of '...           0.0
# ...

# %%
#Total rating count

# %%
male_directed.groupby('vote_average').mean()
# Out:
#               vote_count  releasedate
# vote_average
# 0.0             2.909091  1975.545455
# 0.5             1.000000  2009.000000
# 1.0             1.200000  1994.500000
# 1.3             4.500000  1992.500000
# 1.5             2.000000  1963.000000
# ...                  ...          ...
# 9.2             5.000000  2007.000000
# 9.3             3.000000  1994.000000
# 9.5             1.250000  1976.000000
# 9.8             4.000000  1969.000000
# 10.0            1.304348  1981.695652
#
# [84 rows x 2 columns]

# %%
female_directed
# Out:
#                                                   title  \
# 0                                      Cléo from 5 to 7
# 1                            Portrait of a Lady on Fire
# 2                                               Mustang
# 3                                   Lost in Translation
# 4     Jeanne Dielman, 23, quai du Commerce, 1080 Bru...
# ...                                                 ...
# 4718                                  The Days with Him
# 4719                           Thank You and Good Night
# 4720                                        Last Summer
# 4721                                          Club Zero
# 4722                          Here the Seats Are Vacant
#
#                       genres  releasedate  vote_count  vote_average  \
# 0                      Drama         1962       543.0         7.708
# 1             Drama, Romance         2019      2073.0         8.184
# 2                      Drama         2015      1266.0         7.778
# ...
