# %% [markdown]
# # Pandas (continued)

# %%
import pandas as pd

# %% [markdown]
# ## Quick look at the data
# Using `head` and `describe`, renaming some columns.

# %%
df = pd.read_csv('titanic.csv')

# %%
df.describe()
# Out:
#        Country Name Country Code  \
# count           482          480
# unique            5            3
# top          France          FRA
# freq            160          160
#
#                                                    Series         Series Code  \
# count                                                 480                 480
# unique                                                160                 160
# top     Adjusted net attendance rate, one year before ...  UIS.NARA.AGM1.GPIA
# freq                                                    3                   3
#
#        1991 [YR1991] 1992 [YR1992] 1993 [YR1993] 1994 [YR1994] 1995 [YR1995]  \
# count            480           480           480           480           480
# unique            25            25            35            35            36
# top               ..            ..            ..            ..            ..
# freq             452           452           441           441           440
#
#        1996 [YR1996]  ... 2011 [YR2011] 2012 [YR2012] 2013 [YR2013]  \
# count            480  ...           480           480           480
# unique            36  ...            67            67            95
# top               ..  ...            ..            ..            ..
# freq             440  ...           388           388           359
#
#        2014 [YR2014] 2015 [YR2015] 2016 [YR2016] 2017 [YR2017] 2018 [YR2018]  \
# count            480           480           480           480           480
# unique            97            93            92            96            96
# top               ..            ..            ..            ..            ..
# freq             361           361           358           358           358
#
#        2019 [YR2019] 2020 [YR2020]
# count            480           480
# unique            38             4
# top               ..            ..
# freq             432           466
#
# [4 rows x 34 columns]

# %%
df.describe(include='O')
# Out:
#                            Name   Sex  Ticket    Cabin Embarked
# count                       891   891     891      204      889
# unique                      891     2     681      147        3
# top     Braund, Mr. Owen Harris  male  347082  B96 B98        S
# freq                          1   577       7        4      644

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df = df.rename(columns={'Age': 'age'})
# OR
df.rename(columns={'Age': 'age'}, inplace=True)

# NOT
df.rename(columns={'Age': 'age'})

# %% [markdown]
# ## Data types
# - Numerical: **continuous** vs. **discrete**.
# - Categorical (i.e. non-numerical): **ordinal** vs. **nominal**.

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# ## Dealing with missing values (`nan`)

# %%
df.isna() # OR df.isnull()
df.notna() # OR df.notnull()
# Out:
#      PassengerId  Survived  Pclass  Name   Sex    age  SibSp  Parch  Ticket  \
# 0           True      True    True  True  True   True   True   True    True
# 1           True      True    True  True  True   True   True   True    True
# 2           True      True    True  True  True   True   True   True    True
# 3           True      True    True  True  True   True   True   True    True
# 4           True      True    True  True  True   True   True   True    True
# ..           ...       ...     ...   ...   ...    ...    ...    ...     ...
# 886         True      True    True  True  True   True   True   True    True
# 887         True      True    True  True  True   True   True   True    True
# 888         True      True    True  True  True  False   True   True    True
# 889         True      True    True  True  True   True   True   True    True
# 890         True      True    True  True  True   True   True   True    True
#
#      Fare  Cabin  Embarked
# 0    True  False      True
# 1    True   True      True
# 2    True  False      True
# 3    True   True      True
# 4    True  False      True
# ..    ...    ...       ...
# 886  True  False      True
# 887  True   True      True
# 888  True  False      True
# 889  True   True      True
# 890  True  False      True
#
# [891 rows x 12 columns]

# %%
df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df["age"] = df["age"].fillna("Unknown")

# %%
df.fillna("Unknown", inplace=True)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex      age  \
# 0                              Braund, Mr. Owen Harris    male     22.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female     38.0
# 2                               Heikkinen, Miss. Laina  female     26.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female     35.0
# 4                             Allen, Mr. William Henry    male     35.0
# ..                                                 ...     ...      ...
# 886                              Montvila, Rev. Juozas    male     27.0
# 887                       Graham, Miss. Margaret Edith  female     19.0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female  Unknown
# 889                              Behr, Mr. Karl Howell    male     26.0
# 890                                Dooley, Mr. Patrick    male     32.0
#
#      SibSp  Parch            Ticket     Fare    Cabin Embarked
# 0        1      0         A/5 21171   7.2500  Unknown        S
# 1        1      0          PC 17599  71.2833      C85        C
# 2        0      0  STON/O2. 3101282   7.9250  Unknown        S
# 3        1      0            113803  53.1000     C123        S
# 4        0      0            373450   8.0500  Unknown        S
# ..     ...    ...               ...      ...      ...      ...
# 886      0      0            211536  13.0000  Unknown        S
# 887      0      0            112053  30.0000      B42        S
# 888      1      2        W./C. 6607  23.4500  Unknown        S
# 889      0      0            111369  30.0000     C148        C
# 890      0      0            370376   7.7500  Unknown        Q
#
# [891 rows x 12 columns]

# %% [markdown]
# ## Sorting

# %%
df = pd.read_csv('titanic.csv', sep=";")

# %%
df = df.sort_index(ascending=False)

# %%
df = df.sort_values("Fare", ascending=False)   # df = df.sort_values(by="Fare", ascending=False)

# %%
df = df.sort_values(["Fare", "Age"], ascending=False)

# %%
df["Age"].sort_values(ascending=False)
# Out:
# 630    80.0
# 851    74.0
# 493    71.0
# 96     71.0
# 116    70.5
#        ...
# 466     NaN
# 277     NaN
# 674     NaN
# 413     NaN
# 633     NaN
# Name: Age, Length: 891, dtype: float64

# %%
df["Sex"].sort_values()
# Out:
# 240    female
# 796    female
# 28     female
# 518    female
# 358    female
#         ...
# 253      male
# 735      male
# 743      male
# 407      male
# 633      male
# Name: Sex, Length: 891, dtype: object

# %% [markdown]
# ## Aggregating
# Using `groupby` and computing statistics (`mean`, `quantile`, ...).

# %%
df["Cabin"].value_counts()
# Out:
# B96 B98        4
# C23 C25 C27    4
# G6             4
# E101           3
# D              3
#               ..
# D15            1
# D49            1
# D9             1
# D11            1
# B94            1
# Name: Cabin, Length: 147, dtype: int64

# %%
df["Cabin"].isna().sum()
# Out:
# 687

# %%
# Aggregation on series
df["Age"].max()
# Out:
# 80.0

# %%
df.mean(numeric_only=True)
# Out:
# PassengerId    446.000000
# Survived         0.383838
# Pclass           2.308642
# Age             29.699118
# SibSp            0.523008
# Parch            0.381594
# Fare            32.204208
# dtype: float64

# %%
df.groupby("Sex")["Fare"].mean()
# Out:
# Sex
# female    44.479818
# male      25.523893
# Name: Fare, dtype: float64

# %%
# Remember this
df.groupby("Sex")[["Fare"]].mean()
# Out:
#              Fare
# Sex
# female  44.479818
# male    25.523893

# %%
df.groupby("Sex")[["Fare", "Survived"]].mean()
# Out:
#              Fare  Survived
# Sex
# female  44.479818  0.742038
# male    25.523893  0.188908

# %%
df.groupby("Sex").agg({'Age': 'mean', 'Survived': 'sum'})
# Out:
#               Age  Survived
# Sex
# female  27.915709       233
# male    30.726645       109

# %%
df.groupby("Sex")[["Fare"]].mean()

# %%
df["Pclass"].nunique()
# Out:
# 3

# %%
df["Pclass"].unique()
# Out:
# array([1, 2, 3])

# %%
df.groupby("Sex")[["Fare"]].nunique()
# Out:
#         Fare
# Sex
# female   156
# male     193

# %% [markdown]
# ## Mathematical functions and boolean conditions on columns

# %%
2 * df["Age"]
# Out:
# 679     72.0
# 737     70.0
# 258     70.0
# 438    128.0
# 27      38.0
#        ...
# 822     76.0
# 806     78.0
# 263     80.0
# 597     98.0
# 633      NaN
# Name: Age, Length: 891, dtype: float64

# %%
df["Age"] + df["Age"]
# Out:
# 679     72.0
# 737     70.0
# 258     70.0
# 438    128.0
# 27      38.0
#        ...
# 822     76.0
# 806     78.0
# 263     80.0
# 597     98.0
# 633      NaN
# Name: Age, Length: 891, dtype: float64

# %%
df["Age"] <= 20
# Out:
# 679    False
# 737    False
# 258    False
# 438    False
# 27      True
#        ...
# 822    False
# 806    False
# 263    False
# 597    False
# 633    False
# Name: Age, Length: 891, dtype: bool

# %%
df["Sex"] == "female"
# Out:
# 679    False
# 737    False
# 258     True
# 438    False
# 27     False
#        ...
# 822    False
# 806    False
# 263    False
# 597    False
# 633    False
# Name: Sex, Length: 891, dtype: bool

# %%
(5 >= 2) and (2 > 1)
# Out:
# True

# %%
(df["Age"] >= 20) & (df["Age"] <= 50)
# Out:
# 679     True
# 737     True
# 258     True
# 438    False
# 27     False
#        ...
# 822     True
# 806     True
# 263     True
# 597     True
# 633    False
# Name: Age, Length: 891, dtype: bool

# %%
(df["Pclass"] == 2) | (df["Pclass"] == 3)
# Out:
# 0       True
# 1      False
# 2       True
# 3      False
# 4       True
#        ...
# 886     True
# 887    False
# 888     True
# 889    False
# 890     True
# Name: Pclass, Length: 891, dtype: bool

# %%
((df["Pclass"] == 2) | (df["Pclass"] == 3)).sum()
# Out:
# 675

# %%
# & | ~ are equivalent to and or not in python

# %%
~df["Pclass"].isin([2, 3])
# Out:
# 0      False
# 1       True
# 2      False
# 3       True
# 4      False
#        ...
# 886    False
# 887     True
# 888    False
# 889     True
# 890    False
# Name: Pclass, Length: 891, dtype: bool

# %%
(df["Pclass"] == df["Age"]).sum()
# Out:
# 5

# %% [markdown]
# ## Selecting some rows (aka _indexing_)

# %%
((df["Age"] >= 20) & (df["Age"] <= 30)).sum()
# Out:
# 245

# %%
df[(df["Age"] >= 20) & (df["Age"] <= 30)]
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 2              3         1       3
# 8              9         1       3
# 12            13         0       3
# 23            24         1       1
# ..           ...       ...     ...
# 882          883         0       3
# 883          884         0       2
# 884          885         0       3
# 886          887         0       2
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 12                      Saundercock, Mr. William Henry    male  20.0      0
# 23                        Sloper, Mr. William Thompson    male  28.0      0
# ..                                                 ...     ...   ...    ...
# 882                       Dahlberg, Miss. Gerda Ulrika  female  22.0      0
# 883                      Banfield, Mr. Frederick James    male  28.0      0
# 884                             Sutehall, Mr. Henry Jr    male  25.0      0
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 889                              Behr, Mr. Karl Howell    male  26.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 8        2            347742  11.1333   NaN        S
# 12       0         A/5. 2151   8.0500   NaN        S
# 23       0            113788  35.5000    A6        S
# ..     ...               ...      ...   ...      ...
# 882      0              7552  10.5167   NaN        S
# 883      0  C.A./SOTON 34068  10.5000   NaN        S
# 884      0   SOTON/OQ 392076   7.0500   NaN        S
# 886      0            211536  13.0000   NaN        S
# 889      0            111369  30.0000  C148        C
#
# [245 rows x 12 columns]

# %%
df.loc[(df["Age"] >= 20) & (df["Age"] <= 30), ["Name", "Survived"]]
# Out:
#                                                   Name  Survived
# 0                              Braund, Mr. Owen Harris         0
# 2                               Heikkinen, Miss. Laina         1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)         1
# 12                      Saundercock, Mr. William Henry         0
# 23                        Sloper, Mr. William Thompson         1
# ..                                                 ...       ...
# 882                       Dahlberg, Miss. Gerda Ulrika         0
# 883                      Banfield, Mr. Frederick James         0
# 884                             Sutehall, Mr. Henry Jr         0
# 886                              Montvila, Rev. Juozas         0
# 889                              Behr, Mr. Karl Howell         1
#
# [245 rows x 2 columns]

# %%
mask = (df["Age"] >= 20) & (df["Age"] <= 30)
df.loc[mask, ["Name", "Survived"]]
# Out:
#                                                   Name  Survived
# 0                              Braund, Mr. Owen Harris         0
# 2                               Heikkinen, Miss. Laina         1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)         1
# 12                      Saundercock, Mr. William Henry         0
# 23                        Sloper, Mr. William Thompson         1
# ..                                                 ...       ...
# 882                       Dahlberg, Miss. Gerda Ulrika         0
# 883                      Banfield, Mr. Frederick James         0
# 884                             Sutehall, Mr. Henry Jr         0
# 886                              Montvila, Rev. Juozas         0
# 889                              Behr, Mr. Karl Howell         1
#
# [245 rows x 2 columns]

# %%
df.loc[(df["Age"] >= 20) & (df["Age"] <= 30), "Name"]
# Out:
# 0                                Braund, Mr. Owen Harris
# 2                                 Heikkinen, Miss. Laina
# 8      Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 12                        Saundercock, Mr. William Henry
# 23                          Sloper, Mr. William Thompson
#                              ...
# 882                         Dahlberg, Miss. Gerda Ulrika
# 883                        Banfield, Mr. Frederick James
# 884                               Sutehall, Mr. Henry Jr
# 886                                Montvila, Rev. Juozas
# 889                                Behr, Mr. Karl Howell
# Name: Name, Length: 245, dtype: object

# %% [markdown]
# #### How to make a copy of the data before touching it

# %%
df_backup = df.copy()

# %%
df["Name Original"] = df["Name"]

# %%
df.drop(columns=["Name Original"], inplace=True)

# %% [markdown]
# ## Adding / modifying a column based on another column
# Using `loc` or `np.where`.

# %%
df.loc[(df["Age"] >= 20) & (df["Age"] <= 30), "Name"] = "Anonymous between 20 and 30"
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/_s/5ccjvt852hv4ddn7j5mrvy1m0000gn/T/ipykernel_27063/1496028857.py in <module>
# ----> 1 df.loc[(df["Age"] >= 20) & (df["Age"] <= 30), "Name"] = "Anonymous between 20 and 30"
#
# NameError: name 'df' is not defined

# %%
df.loc[(df["Age"] >= 20) & (df["Age"] <= 30), "AgeRange"] = "Between 20 and 30"

# %%
df.loc[(df["Age"] >= 20) & (df["Age"] <= 30), "AgeRange"]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/_s/5ccjvt852hv4ddn7j5mrvy1m0000gn/T/ipykernel_27063/1189567960.py in <module>
# ----> 1 df.loc[(df["Age"] >= 20) & (df["Age"] <= 30), "AgeRange"]
#
# NameError: name 'df' is not defined

# %%
df.loc[df["Age"] <= 20, "AgeRange"] = "Below 20"
df.loc[(df["Age"] > 20) & (df["Age"] <= 30), "AgeRange"] = "Between 20 and 30"
df.loc[df["Age"] > 30, "AgeRange"] = "Above 30"
df.loc[df["Age"].isna()] = "Missing"

# %%
fa
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Age'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /var/folders/_s/5ccjvt852hv4ddn7j5mrvy1m0000gn/T/ipykernel_31157/15362545.py in <module>
# ----> 1 df.loc[df["Age"] > 30, "AgeRange"]
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3503             if self.columns.nlevels > 1:
#    3504                 return self._getitem_multilevel(key)
# -> 3505             indexer = self.columns.get_loc(key)
#    3506             if is_integer(indexer):
#    3507                 indexer = [indexer]
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
# -> 3631                 raise KeyError(key) from err
#    3632             except TypeError:
#    3633                 # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'Age'

# %%
df.loc[df["Pclass"] == 1, "Pclass_agg"] = "1st"
df.loc[(df["Pclass"] == 2) | (df["Pclass"] == 3), "Pclass_agg"] = "2nd or 3rd"

# %%
df.loc[df["Pclass"] == 1, "Pclass_agg"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Pclass'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /var/folders/_s/5ccjvt852hv4ddn7j5mrvy1m0000gn/T/ipykernel_31157/3687818125.py in <module>
# ----> 1 df.loc[df["Pclass"] == 1, "Pclass_agg"]
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3503             if self.columns.nlevels > 1:
#    3504                 return self._getitem_multilevel(key)
# -> 3505             indexer = self.columns.get_loc(key)
#    3506             if is_integer(indexer):
#    3507                 indexer = [indexer]
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
# -> 3631                 raise KeyError(key) from err
#    3632             except TypeError:
#    3633                 # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'Pclass'

# %%
df["Name"]
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %% [markdown]
# ### Indexes

# %%
df.set_index("Name", inplace=True)

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 df
#
# NameError: name 'df' is not defined

# %%
df["Ticket"].loc.["Heikkinen, Miss. Laina"]
# Out:
#   File "/var/folders/_s/5ccjvt852hv4ddn7j5mrvy1m0000gn/T/ipykernel_31157/2660651512.py", line 1
#     df["Ticket"].loc.["Heikkinen, Miss. Laina"]
#                      ^
# SyntaxError: invalid syntax

# %%
df["Ticket"].iloc[3:6]
# Out:
# Name
# Futrelle, Mrs. Jacques Heath (Lily May Peel)    113803
# Allen, Mr. William Henry                        373450
# Moran, Mr. James                                330877
# Name: Ticket, dtype: object

# %%
df.iloc[3:6, 5]
# Out:
# Name
# Futrelle, Mrs. Jacques Heath (Lily May Peel)    1
# Allen, Mr. William Henry                        0
# Moran, Mr. James                                0
# Name: SibSp, dtype: int64

# %%
df.reset_index(drop=False, inplace=True)

# %% [markdown]
# ## String functions

# %%
df = pd.read_csv('titanic.csv', sep=";")

# %%
df["Last Name"] = df["Name"].str.split(',').str[0]
df["First Name"] = df["Name"].str.split(',').str[1]

# %%
df[['Last Name', 'First Name']] = df["Name"].str.extract('(.*), (.*)').rename(columns={0: 'Last Name', 1: 'First Name'})

# %%
df[['Last Name', 'First Name']] = df["Name"].str.extract('(.*), (.*)')

# %%
df["Last Name"] = df["Last Name"].str.upper()

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked  Last Name  \
# 0        0         A/5 21171   7.2500   NaN        S     BRAUND
# 1        0          PC 17599  71.2833   C85        C    CUMINGS
# 2        0  STON/O2. 3101282   7.9250   NaN        S  HEIKKINEN
# 3        0            113803  53.1000  C123        S   FUTRELLE
# 4        0            373450   8.0500   NaN        S      ALLEN
# ..     ...               ...      ...   ...      ...        ...
# 886      0            211536  13.0000   NaN        S   MONTVILA
# 887      0            112053  30.0000   B42        S     GRAHAM
# 888      2        W./C. 6607  23.4500   NaN        S   JOHNSTON
# 889      0            111369  30.0000  C148        C       BEHR
# 890      0            370376   7.7500   NaN        Q     DOOLEY
#
#                                      First Name
# 0                               Mr. Owen Harris
# 1    Mrs. John Bradley (Florence Briggs Thayer)
# 2                                   Miss. Laina
# 3            Mrs. Jacques Heath (Lily May Peel)
# 4                             Mr. William Henry
# ..                                          ...
# 886                                 Rev. Juozas
# 887                        Miss. Margaret Edith
# 888              Miss. Catherine Helen "Carrie"
# 889                             Mr. Karl Howell
# 890                                 Mr. Patrick
#
# [891 rows x 14 columns]

# %% [markdown]
# ## Join two dataframes
# Using `merge` (not `join`!...)

# %%
df_proba = df.groupby("Sex")[["Survived", "Fare"]].mean().reset_index()
df_proba
# Out:
#       Sex  Survived       Fare
# 0  female  0.742038  44.479818
# 1    male  0.188908  25.523893

# %%
df_merged = df.merge(df_proba, how="inner", on="Sex")

# %%
proba, left_on="Sex", right_on="Sex", how="inner", suffixes=('_original', '_avg'))
# Out:
#      PassengerId  Survived_original  Pclass  \
# 0              1                  0       3
# 1              5                  0       3
# 2              6                  0       3
# 3              7                  0       1
# 4              8                  0       3
# ..           ...                ...     ...
# 886          881                  1       2
# 887          883                  0       3
# 888          886                  0       3
# 889          888                  1       1
# 890          889                  0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                         Braund, Mr. Owen Harris    male  22.0      1      0
# 1                        Allen, Mr. William Henry    male  35.0      0      0
# 2                                Moran, Mr. James    male   NaN      0      0
# 3                         McCarthy, Mr. Timothy J    male  54.0      0      0
# 4                  Palsson, Master. Gosta Leonard    male   2.0      3      1
# ..                                            ...     ...   ...    ...    ...
# 886  Shelley, Mrs. William (Imanita Parrish Hall)  female  25.0      0      1
# 887                  Dahlberg, Miss. Gerda Ulrika  female  22.0      0      0
# 888          Rice, Mrs. William (Margaret Norton)  female  39.0      0      5
# 889                  Graham, Miss. Margaret Edith  female  19.0      0      0
# 890      Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1      2
#
#          Ticket  Fare_original Cabin Embarked Last Name  \
# 0     A/5 21171         7.2500   NaN        S    BRAUND
# 1        373450         8.0500   NaN        S     ALLEN
# 2        330877         8.4583   NaN        Q     MORAN
# 3         17463        51.8625   E46        S  MCCARTHY
# 4        349909        21.0750   NaN        S   PALSSON
# ..          ...            ...   ...      ...       ...
# 886      230433        26.0000   NaN        S   SHELLEY
# 887        7552        10.5167   NaN        S  DAHLBERG
# 888      382652        29.1250   NaN        Q      RICE
# 889      112053        30.0000   B42        S    GRAHAM
# 890  W./C. 6607        23.4500   NaN        S  JOHNSTON
#
#                               First Name  Survived_avg   Fare_avg
# 0                        Mr. Owen Harris      0.188908  25.523893
# 1                      Mr. William Henry      0.188908  25.523893
# 2                              Mr. James      0.188908  25.523893
# 3                          Mr. Timothy J      0.188908  25.523893
# 4                  Master. Gosta Leonard      0.188908  25.523893
# ..                                   ...           ...        ...
# 886  Mrs. William (Imanita Parrish Hall)      0.742038  44.479818
# 887                   Miss. Gerda Ulrika      0.742038  44.479818
# 888       Mrs. William (Margaret Norton)      0.742038  44.479818
# 889                 Miss. Margaret Edith      0.742038  44.479818
# 890       Miss. Catherine Helen "Carrie"      0.742038  44.479818
#
# [891 rows x 16 columns]

# %% [markdown]
# ## Concatenate two dataframes

# %%
df1 = df[df.Age <= 20]
df2 = df[df.Age > 20]

# %%
len(df1)
# Out:
# 179

# %%
len(df2)
# Out:
# 535

# %%
df_reconcat = pd.concat([df1, df2])

# %%
df_reconcat
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 7              8         0       3        Palsson, Master. Gosta Leonard
# 9             10         1       2   Nasser, Mrs. Nicholas (Adele Achem)
# 10            11         1       3       Sandstrom, Miss. Marguerite Rut
# 12            13         0       3        Saundercock, Mr. William Henry
# 14            15         0       3  Vestrom, Miss. Hulda Amanda Adolfina
# ..           ...       ...     ...                                   ...
# 884          885         0       3                Sutehall, Mr. Henry Jr
# 885          886         0       3  Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                 Montvila, Rev. Juozas
# 889          890         1       1                 Behr, Mr. Karl Howell
# 890          891         0       3                   Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch           Ticket     Fare Cabin Embarked  \
# 7      male   2.0      3      1           349909  21.0750   NaN        S
# 9    female  14.0      1      0           237736  30.0708   NaN        C
# 10   female   4.0      1      1          PP 9549  16.7000    G6        S
# 12     male  20.0      0      0        A/5. 2151   8.0500   NaN        S
# 14   female  14.0      0      0           350406   7.8542   NaN        S
# ..      ...   ...    ...    ...              ...      ...   ...      ...
# 884    male  25.0      0      0  SOTON/OQ 392076   7.0500   NaN        S
# 885  female  39.0      0      5           382652  29.1250   NaN        Q
# 886    male  27.0      0      0           211536  13.0000   NaN        S
# 889    male  26.0      0      0           111369  30.0000  C148        C
# 890    male  32.0      0      0           370376   7.7500   NaN        Q
#
#        Last Name                      First Name
# 7        PALSSON           Master. Gosta Leonard
# 9         NASSER     Mrs. Nicholas (Adele Achem)
# 10     SANDSTROM            Miss. Marguerite Rut
# 12   SAUNDERCOCK               Mr. William Henry
# 14       VESTROM     Miss. Hulda Amanda Adolfina
# ..           ...                             ...
# 884     SUTEHALL                    Mr. Henry Jr
# 885         RICE  Mrs. William (Margaret Norton)
# 886     MONTVILA                     Rev. Juozas
# 889         BEHR                 Mr. Karl Howell
# 890       DOOLEY                     Mr. Patrick
#
# [714 rows x 14 columns]

# %% [markdown]
# ## One-hot encoding
# Using `get_dummies`.

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked  Last Name  \
# 0        0         A/5 21171   7.2500   NaN        S     BRAUND
# 1        0          PC 17599  71.2833   C85        C    CUMINGS
# 2        0  STON/O2. 3101282   7.9250   NaN        S  HEIKKINEN
# 3        0            113803  53.1000  C123        S   FUTRELLE
# 4        0            373450   8.0500   NaN        S      ALLEN
# ..     ...               ...      ...   ...      ...        ...
# 886      0            211536  13.0000   NaN        S   MONTVILA
# 887      0            112053  30.0000   B42        S     GRAHAM
# 888      2        W./C. 6607  23.4500   NaN        S   JOHNSTON
# 889      0            111369  30.0000  C148        C       BEHR
# 890      0            370376   7.7500   NaN        Q     DOOLEY
#
#                                      First Name
# 0                               Mr. Owen Harris
# 1    Mrs. John Bradley (Florence Briggs Thayer)
# 2                                   Miss. Laina
# 3            Mrs. Jacques Heath (Lily May Peel)
# 4                             Mr. William Henry
# ..                                          ...
# 886                                 Rev. Juozas
# 887                        Miss. Margaret Edith
# 888              Miss. Catherine Helen "Carrie"
# 889                             Mr. Karl Howell
# 890                                 Mr. Patrick
#
# [891 rows x 14 columns]

# %%
pd.get_dummies(df["Embarked"]).astype(bool)
# Out:
#          C      Q      S
# 0    False  False   True
# 1     True  False  False
# 2    False  False   True
# 3    False  False   True
# 4    False  False   True
# ..     ...    ...    ...
# 886  False  False   True
# 887  False  False   True
# 888  False  False   True
# 889   True  False  False
# 890  False   True  False
#
# [891 rows x 3 columns]

# %% [markdown]
# ## Pivot and unpivot

# %%
df.pivot_table(index=["Sex"], columns=["Pclass"], values=["Survived"], aggfunc="mean")
# Out:
#         Survived
# Pclass         1         2         3
# Sex
# female  0.968085  0.921053  0.500000
# male    0.368852  0.157407  0.135447

# %%
df.pivot_table(columns=["Pclass"], values=["Survived"])
# Out:
# Pclass          1         2         3
# Survived  0.62963  0.472826  0.242363

# %%
df.pivot_table(index=["Sex"], values=["Survived"])
# Out:
#         Survived
# Sex
# female  0.742038
# male    0.188908

# %%
df_indicator = pd.read_csv('co2_emissions.csv', sep=',')

# %%
len(df_indicator)
# Out:
# 266

# %%
df_melted = df_indicator.melt(value_vars=df_indicator.columns[34:-1], var_name="Year",
                              id_vars=["Country Name", "Indicator Name"],
                              value_name="Value")

# %%
df_melted.dropna(subset=["Value"], inplace=True)

# %%
df_melted.dropna(subset=["Value"])
# Out:
#                      Country Name                          Indicator Name  \
# 1     Africa Eastern and Southern  CO2 emissions (metric tons per capita)
# 2                     Afghanistan  CO2 emissions (metric tons per capita)
# 3      Africa Western and Central  CO2 emissions (metric tons per capita)
# 4                          Angola  CO2 emissions (metric tons per capita)
# 5                         Albania  CO2 emissions (metric tons per capita)
# ...                           ...                                     ...
# 7974                        Samoa  CO2 emissions (metric tons per capita)
# 7976                  Yemen, Rep.  CO2 emissions (metric tons per capita)
# 7977                 South Africa  CO2 emissions (metric tons per capita)
# 7978                       Zambia  CO2 emissions (metric tons per capita)
# 7979                     Zimbabwe  CO2 emissions (metric tons per capita)
#
#       Year     Value
# 1     1990  0.982136
# 2     1990  0.222538
# 3     1990  0.473669
# 4     1990  0.554586
# 5     1990  1.819542
# ...    ...       ...
# 7974  2019  1.415729
# 7976  2019  0.351859
# 7977  2019  7.568640
# 7978  2019  0.369958
# 7979  2019  0.765894
#
# [7147 rows x 4 columns]
