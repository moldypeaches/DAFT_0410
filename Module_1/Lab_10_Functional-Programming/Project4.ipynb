# %%
import pandas as pd

# %%
df = pd.read_csv('Metadata.csv')

# %%
df.head()
# Out:
#    Unnamed: 0           Unnamed: 1  \
# 0         NaN        Variable name
# 1         NaN             recordID
# 2         NaN           orderCarni
# 3         NaN          familyCarni
# 4         NaN  scientificNameCarni
#
#                                           Unnamed: 2    Unnamed: 3  \
# 0                                Variable definition  Storage type
# 1          Numerical identifier for the diet record.       Numeric
# 2  The order of the mammal-consumer species the d...        Factor
# 3  The family of the mammal-consumer species the ...        Factor
# 4  The binomial name of the mammal-consumer speci...        Factor
#
#     Unnamed: 4       Unnamed: 5            Unnamed: 6  \
# 0    Data Type  Numercial Range  Number of categories
# 1   Continuous          1-29351                   NaN
# 2  Categorical              NaN                     5
# 3  Categorical              NaN                    15
# 4  Categorical              NaN                   103
#
# ...

# %%
df
# Out:
#     Unnamed: 0                   Unnamed: 1  \
# 0          NaN                Variable name
# 1          NaN                     recordID
# 2          NaN                   orderCarni
# 3          NaN                  familyCarni
# 4          NaN          scientificNameCarni
# 5          NaN              commonNameCarni
# 6          NaN                     sexCarni
# 7          NaN               lifeStageCarni
# 8          NaN                     foodType
# 9          NaN                    orderPrey
# 10         NaN                   familyPrey
# 11         NaN                    genusPrey
# 12         NaN                  speciesPrey
# 13         NaN           scientificNamePrey
# 14         NaN               commonNamePrey
# 15         NaN          anthropogenicOrigin
# 16         NaN                taxonRankPrey
# 17         NaN                   percentage
# 18         NaN              percentageError
# 19         NaN          dataBasisFromSource
# ...

# %%
df.drop(columns='Unnamed: 0', inplace=True)

# %%
df
# Out:
#                      Unnamed: 1  \
# 0                 Variable name
# 1                      recordID
# 2                    orderCarni
# 3                   familyCarni
# 4           scientificNameCarni
# 5               commonNameCarni
# 6                      sexCarni
# 7                lifeStageCarni
# 8                      foodType
# 9                     orderPrey
# 10                   familyPrey
# 11                    genusPrey
# 12                  speciesPrey
# 13           scientificNamePrey
# 14               commonNamePrey
# 15          anthropogenicOrigin
# 16                taxonRankPrey
# 17                   percentage
# 18              percentageError
# 19          dataBasisFromSource
# 20  sampleSizeScatStomachTissue
# 21     sampleSizeKillsPreyItems
# 22                    startYear
# 23                      endYear
# 24                   startMonth
# 25                     endMonth
# 26           fixedBetweenMonths
# 27               startDayOfYear
# ...

# %%
df.rename(columns={"Unnamed: 1": "variable_name", "Unnamed: 2":'variable_definition', 'Unnamed: 3':'storage_type', 'Unnamed: 4':'data_type',
                   'Unnamed: 5':'numercial_range', 'Unnamed: 6':'Number of categories', 'Unnamed: 7':'Example of categories'})
