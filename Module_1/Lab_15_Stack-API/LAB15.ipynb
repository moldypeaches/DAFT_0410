# %% [markdown]
# # StackAPI
#
# #### Import the necessary libraries here:

# %%
import requests
import json
import pandas as pd 
from stackapi import StackAPI
SITE = StackAPI('stackoverflow')
comments = SITE.fetch('comments')
SITE
# Out:
# <Stack Overflow> v:<2.2> endpoint: comments  Last URL: https://api.stackexchange.com/2.2/comments/?pagesize=100&page=5&filter=default&site=stackoverflow

# %%
response = requests.get('https://api.stackexchange.com/2.2/comments/?pagesize=100&page=5&filter=default&site=stackoverflow')

# %% [markdown]
# #### Question 1: Find the questions and answers of last month.

# %%
questions = SITE.fetch('questions', fromdate=1679266800, todate= 1681941600)
questions
# Out:
# {'backoff': 0,
#  'has_more': True,
#  'page': 5,
#  'quota_max': 300,
#  'quota_remaining': 276,
#  'total': 0,
#  'items': [{'tags': ['python-3.x', 'pagination', 'tweepy', 'sna'],
#    'owner': {'reputation': 567,
#     'user_id': 6087589,
#     'user_type': 'registered',
#     'accept_rate': 83,
#     'profile_image': 'https://www.gravatar.com/avatar/508f85f9b3e192f11456dbff7a6a840c?s=256&d=identicon&r=PG&f=1',
#     'display_name': 'anitasp',
#     'link': 'https://stackoverflow.com/users/6087589/anitasp'},
#    'is_answered': True,
#    'view_count': 118,
#    'answer_count': 1,
#    'score': 0,
#    'last_activity_date': 1682354049,
#    'creation_date': 1681532006,
#    'last_edit_date': 1682195288,
#    'question_id': 76020320,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/76020320/tweepy-get-followers-list',
#    'title': 'Tweepy get followers list'},
#   {'tags': ['node.js', 'next.js', 'next-auth'],
# ...

# %%
answers = SITE.fetch('answers', fromdate=1679266800, todate= 1681941600)
answers
# Out:
# {'backoff': 0,
#  'has_more': True,
#  'page': 5,
#  'quota_max': 300,
#  'quota_remaining': 271,
#  'total': 0,
#  'items': [{'owner': {'reputation': 13737,
#     'user_id': 6083423,
#     'user_type': 'registered',
#     'accept_rate': 82,
#     'profile_image': 'https://i.stack.imgur.com/f99j5.jpg?s=256&g=1',
#     'display_name': 'Life is complex',
#     'link': 'https://stackoverflow.com/users/6083423/life-is-complex'},
#    'is_accepted': False,
#    'score': 4,
#    'last_activity_date': 1682354049,
#    'last_edit_date': 1682354049,
#    'creation_date': 1681839794,
#    'answer_id': 76047609,
#    'question_id': 76020320,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 662,
#     'user_id': 14307703,
#     'user_type': 'registered',
#     'profile_image': 'https://i.stack.imgur.com/kMZEc.jpg?s=256&g=1',
#     'display_name': 'Hazzu',
#     'link': 'https://stackoverflow.com/users/14307703/hazzu'},
#    'is_accepted': False,
#    'score': 1,
# ...

# %% [markdown]
# #### Question 2: Find the most voted question today with at least a score of 5 and tagged with 'python'.

# %%
voted_question = SITE.fetch('questions', fromdate=1681941600, todate= 1681941600, min=5, tagged='python', sort='votes')
voted_question
# Out:
# {'backoff': 0,
#  'has_more': False,
#  'page': 1,
#  'quota_max': 300,
#  'quota_remaining': 267,
#  'total': 0,
#  'items': []}

# %% [markdown]
# #### Question 3: Find the answers with id 6784 and 6473.

# %%
answers_id = SITE.fetch('answers',
