# %%
import config
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import pprint
import pandas as pd

# %%
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id= config.c_id,
                                                           client_secret= config.c_se))

# %%
#FIRST PLAYLIST

playlist = sp.user_playlist_tracks("spotify", "1LcuQZV759hx8gHNptZ5yI",market="GB")

# %%
def get_playlist_tracks(username, playlist_id):
    results = sp.user_playlist_tracks(username,playlist_id,market="GB")
    tracks = results['items']
    while results['next']:
        results = sp.next(results)
        tracks.extend(results['items'])
    return tracks

# %%
tracks=get_playlist_tracks("spotify", "1LcuQZV759hx8gHNptZ5yI")

# %%
list_of_audio_features=[]
for item in range(0,119):
    #print (tracks[item]["track"]["id"])
    list_of_audio_features.append(sp.audio_features(tracks[item]["track"]["id"])[0])

# %%
df=pd.DataFrame(list_of_audio_features)    
df=df[["danceability","energy","loudness","speechiness","acousticness",
    "instrumentalness","liveness","valence","tempo","id","duration_ms"]]

df
# Out:
#      danceability  energy  loudness  speechiness  acousticness  \
# 0           0.895   0.404   -10.241       0.1080      0.218000
# 1           0.705   0.549    -8.171       0.1840      0.477000
# 2           0.806   0.545   -10.199       0.0569      0.000086
# 3           0.765   0.776    -7.991       0.0326      0.033500
# 4           0.927   0.525    -8.256       0.0667      0.274000
# ..            ...     ...       ...          ...           ...
# 114         0.888   0.632    -3.872       0.2190      0.190000
# 115         0.872   0.610    -7.965       0.0421      0.084700
# 116         0.823   0.648   -10.107       0.0450      0.040300
# 117         0.910   0.757    -6.975       0.1010      0.002750
# 118         0.859   0.642    -9.887       0.0509      0.000595
#
#      instrumentalness  liveness  valence    tempo                      id  \
# 0              0.3160    0.0974    0.176  112.993  3q6ql0KuUMPBolEfd8LhbE
# 1              0.4790    0.0888    0.274   84.014  6LRY3cFPXnM9WXKXrKPKJr
# 2              0.8650    0.1030    0.672  124.998  72heTYSB1VaSn8LBR7JKS6
# 3              0.6170    0.1340    0.708  104.015  5nLAheg0AIva7wue6gUiNN
# 4              0.2380    0.0672    0.778  118.023  1vMGIZbIkpaLSagdF2ygcV
# ..                ...       ...      ...      ...                     ...
# 114            0.0000    0.1010    0.662   91.979  2NBQmPrOEEjA8VbeWOQGxO
# 115            0.3220    0.6430    0.559  114.995  4Vldw0eUgCbhgyxAWY6JMk
# 116            0.7670    0.1740    0.962  124.015  7DSe9aWkpnbDQTTRikkpYp
# 117            0.0116    0.0636    0.596  117.992  2akFLoxJNjGxwtUX0XgjSn
# 118            0.1170    0.0824    0.860  122.984  3JVDYGvMsdMFhEckLwiCp4
#
#      duration_ms
# 0         284602
# 1         174286
# 2         323200
# 3         234519
# 4         198305
# ..           ...
# 114       266067
# 115       311493
# 116       386893
# 117       360222
# 118       470134
#
# [119 rows x 11 columns]

# %%
#SECOND PLAYLIST

# %%
playlist2 = sp.user_playlist_tracks("spotify", "1za8ZVd7nSGbfBLJYrYkxr",market="GB")

# %%
tracks=get_playlist_tracks("spotify", "1za8ZVd7nSGbfBLJYrYkxr")

# %%
list_of_audio_features=[]
for item in range(0,300):
    #print (tracks[item]["track"]["id"])
    list_of_audio_features.append(sp.audio_features(tracks[item]["track"]["id"])[0])

# %%
df2=pd.DataFrame(list_of_audio_features)    
df2=df2[["danceability","energy","loudness","speechiness","acousticness",
    "instrumentalness","liveness","valence","tempo","id","duration_ms"]]

df2
# Out:
#      danceability  energy  loudness  speechiness  acousticness  \
# 0           0.699   0.521    -6.734       0.0268       0.14800
# 1           0.436   0.654    -8.153       0.1600       0.42000
# 2           0.946   0.271   -11.985       0.1680       0.04510
# 3           0.871   0.505   -12.594       0.0326       0.40100
# 4           0.700   0.725   -11.433       0.0492       0.04390
# ..            ...     ...       ...          ...           ...
# 295         0.858   0.678    -3.870       0.0469       0.07610
# 296         0.907   0.866   -11.054       0.1100       0.11300
# 297         0.811   0.781    -6.333       0.0428       0.37600
# 298         0.806   0.933    -3.550       0.1340       0.00195
# 299         0.499   0.671    -6.774       0.0561       0.11400
#
#      instrumentalness  liveness  valence    tempo                      id  \
# 0            0.000952    0.1330   0.7930  107.053  7aHMTN6QuGwUP0z4Vvu8Z7
# 1            0.000000    0.3930   0.5230  139.680  2tHdQjwO5zN86MLF7ZtU1X
# 2            0.885000    0.0488   0.4930  119.996  6KjOnWGPQyQtNY1U8tG34u
# 3            0.000221    0.2140   0.8910  107.405  4KOQk1FhOOIfuHMZahP5Wa
# 4            0.851000    0.1250   0.1290  116.824  0vryyKyxCFXT0gg670yNEw
# ..                ...       ...      ...      ...                     ...
# 295          0.000000    0.0741   0.9220  117.009  0laYHRpNTS6i8FXdupHkJ4
# 296          0.364000    0.0911   0.5540  140.456  7my6XUhpB0qHMoVRe5haBH
# 297          0.001000    0.1210   0.8240  107.007  6hgoYQDUcPyCz7LcTUHKxa
# 298          0.703000    0.0497   0.6720  125.996  2EkOwCBWjcFfhychOKcY7j
# 299          0.016900    0.1480   0.0557  124.994  28JBD8p18xNuOfyV7Cotdn
#
#      duration_ms
# 0         184893
# 1         154749
# 2         232907
# 3         191187
# 4         403706
# ..           ...
# 295       188453
# 296       290090
# 297       219813
# 298       244165
# 299       336924
#
# [300 rows x 11 columns]

# %%
#THIRD PLAYLIST

# %%
playlist3 = sp.user_playlist_tracks("spotify", "1dhdpHBl7D3iKkVwmEPr73",market="GB")

# %%
tracks=get_playlist_tracks("spotify", "1dhdpHBl7D3iKkVwmEPr73")

# %%
list_of_audio_features=[]
for item in range(0,500):
    #print (tracks[item]["track"]["id"])
    list_of_audio_features.append(sp.audio_features(tracks[item]["track"]["id"])[0])

# %%
df3=pd.DataFrame(list_of_audio_features)    
df3=df3[["danceability","energy","loudness","speechiness","acousticness",
    "instrumentalness","liveness","valence","tempo","id","duration_ms"]]

df3
# Out:
#      danceability  energy  loudness  speechiness  acousticness  \
# 0           0.434   0.441   -12.769       0.0652        0.7310
# 1           0.707   0.338    -8.322       0.0372        0.1580
# 2           0.804   0.306   -15.984       0.0374        0.7280
# 3           0.625   0.356   -10.078       0.0442        0.4820
# 4           0.839   0.233   -13.539       0.0413        0.7450
# ..            ...     ...       ...          ...           ...
# 495         0.657   0.491    -5.304       0.0351        0.0814
# 496         0.663   0.485    -9.468       0.1490        0.6340
# 497         0.612   0.203   -20.308       0.0346        0.9220
# 498         0.543   0.608    -6.708       0.0311        0.1190
# 499         0.874   0.364   -12.326       0.0983        0.2180
#
#      instrumentalness  liveness  valence    tempo                      id  \
# 0            0.014800    0.0871    0.466  148.348  1O56AVKWDXwzB7bLHusene
# 1            0.626000    0.0606    0.150  124.841  4IoqGTH2D6zMrGzg9gW0DL
# 2            0.775000    0.1030    0.693  106.172  5FYlubj1nGOUYmJ57ezUXu
# 3            0.000010    0.0640    0.480  210.032  58Oll9yVFiS8GruxIWQMkO
# 4            0.747000    0.1050    0.777  125.597  0fxjsll9jmmRgMFbwdp4Xg
# ..                ...       ...      ...      ...                     ...
# 495          0.000535    0.0528    0.354  122.972  09CJ3mgu5wVoZ7iVKaoxsO
# 496          0.000463    0.2800    0.871  184.804  3lQNVAMwqcxFCJj8mI1izh
# 497          0.701000    0.1200    0.652   74.983  3Gkg9mRJXJgNpozGIs7Nrm
# 498          0.000940    0.3380    0.368  141.023  4FvqAI5GwPspJE3TkMGnEb
# 499          0.026300    0.1010    0.675   86.004  3NiYvMjp5A3FZmP3dojS8k
#
#      duration_ms
# 0         321040
# 1         277653
# 2         536255
# 3         151942
# 4         194293
# ..           ...
# 495       257133
# 496       213213
# 497       446818
# 498       245843
# 499       216693
#
# [500 rows x 11 columns]

# %%
#FOURTH PLAYLIST

# %%
playlist4 = sp.user_playlist_tracks("spotify", "24cVLClMLrf7jCT93LJ1CE",market="GB")

# %%
tracks=get_playlist_tracks("spotify", "24cVLClMLrf7jCT93LJ1CE")

# %%
list_of_audio_features=[]
for item in range(0,400):
    #print (tracks[item]["track"]["id"])
    list_of_audio_features.append(sp.audio_features(tracks[item]["track"]["id"])[0])

# %%
df4=pd.DataFrame(list_of_audio_features)    
df4=df4[["danceability","energy","loudness","speechiness","acousticness",
    "instrumentalness","liveness","valence","tempo","id","duration_ms"]]

df4
# Out:
#      danceability  energy  loudness  speechiness  acousticness  \
# 0           0.616   0.412   -11.884       0.0297      0.016900
# 1           0.293   0.244   -14.673       0.0302      0.975000
# 2           0.714   0.576   -11.721       0.1110      0.525000
# 3           0.432   0.512    -6.967       0.0255      0.001170
# 4           0.310   0.573    -7.530       0.0308      0.535000
# ..            ...     ...       ...          ...           ...
# 395         0.528   0.826    -6.898       0.0366      0.216000
# 396         0.901   0.654   -12.354       0.0405      0.286000
# 397         0.619   0.868    -6.571       0.0363      0.009230
# 398         0.196   0.313   -17.095       0.0437      0.953000
# 399         0.547   0.764   -12.552       0.0419      0.000523
#
#      instrumentalness  liveness  valence    tempo                      id  \
# 0            0.826000    0.1770   0.6170  139.999  5f4AMAsvmUXxRNjloZF8AJ
# 1            0.038500    0.0900   0.0627   74.397  1ySJ9oi6r5I8PnwQun9n3X
# 2            0.000242    0.0816   0.5290  135.950  77UZNWGdvEchg0gcTRTcBz
# 3            0.000268    0.1080   0.0593   79.950  597X2rGKQA4nOujF7YrAbW
# 4            0.453000    0.1020   0.4400  188.078  39qIpVZzCIvNZgcsSf5Ghg
# ..                ...       ...      ...      ...                     ...
# 395          0.438000    0.0975   0.1820  123.012  7EMoSEOUoS90lQdXll2mak
# 396          0.010100    0.0701   0.9040  138.977  4ZTSygIiwgD9jJE2dc4w78
# 397          0.495000    0.3400   0.7450  118.836  0PvaYr8WfHQa15r7TfmgDN
# 398          0.963000    0.0864   0.0747  143.676  4i6HWnWWkpoUyUi0SZ3lZ8
# 399          0.000018    0.2850   0.7220  117.722  2ItPID4dgSL1t1ZbZCrg5S
#
#      duration_ms
# 0         221044
# 1         209533
# 2         220667
# 3         271894
# 4         264787
# ..           ...
# 395       299746
# 396       388160
# 397       236640
# 398       305500
# 399       239493
#
# [400 rows x 11 columns]

# %%
final_dataset = pd.concat([df, df2, df3, df4])

# %%
final_dataset
# Out:
#      danceability  energy  loudness  speechiness  acousticness  \
# 0           0.895   0.404   -10.241       0.1080      0.218000
# 1           0.705   0.549    -8.171       0.1840      0.477000
# 2           0.806   0.545   -10.199       0.0569      0.000086
# 3           0.765   0.776    -7.991       0.0326      0.033500
# 4           0.927   0.525    -8.256       0.0667      0.274000
# ..            ...     ...       ...          ...           ...
# 395         0.528   0.826    -6.898       0.0366      0.216000
# 396         0.901   0.654   -12.354       0.0405      0.286000
# 397         0.619   0.868    -6.571       0.0363      0.009230
# 398         0.196   0.313   -17.095       0.0437      0.953000
# 399         0.547   0.764   -12.552       0.0419      0.000523
#
#      instrumentalness  liveness  valence    tempo                      id  \
# 0            0.316000    0.0974   0.1760  112.993  3q6ql0KuUMPBolEfd8LhbE
# 1            0.479000    0.0888   0.2740   84.014  6LRY3cFPXnM9WXKXrKPKJr
# 2            0.865000    0.1030   0.6720  124.998  72heTYSB1VaSn8LBR7JKS6
# 3            0.617000    0.1340   0.7080  104.015  5nLAheg0AIva7wue6gUiNN
# 4            0.238000    0.0672   0.7780  118.023  1vMGIZbIkpaLSagdF2ygcV
# ..                ...       ...      ...      ...                     ...
# 395          0.438000    0.0975   0.1820  123.012  7EMoSEOUoS90lQdXll2mak
# 396          0.010100    0.0701   0.9040  138.977  4ZTSygIiwgD9jJE2dc4w78
# 397          0.495000    0.3400   0.7450  118.836  0PvaYr8WfHQa15r7TfmgDN
# 398          0.963000    0.0864   0.0747  143.676  4i6HWnWWkpoUyUi0SZ3lZ8
# 399          0.000018    0.2850   0.7220  117.722  2ItPID4dgSL1t1ZbZCrg5S
#
#      duration_ms
# 0         284602
# 1         174286
# 2         323200
# 3         234519
# 4         198305
# ..           ...
# 395       299746
# 396       388160
# 397       236640
# 398       305500
# 399       239493
#
# [1319 rows x 11 columns]

# %%
final_dataset.to_csv("project6.csv", mode="a", index=True)
