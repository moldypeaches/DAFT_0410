# %%
import config 
import spotipy
import json
from spotipy.oauth2 import SpotifyClientCredentials

sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id= config.c_id,
                                                        client_secret= config.c_se))

# %%
import pandas as pd
import numpy as np
from plotly import express as px
from sklearn.cluster import KMeans
from sklearn.preprocessing import OneHotEncoder
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from matplotlib import pyplot as plt

# %%
spotipy = pd.read_csv('project6.csv', sep=',')

# %%
spotipy
# Out:
#       Unnamed: 0  danceability  energy  loudness  speechiness  acousticness  \
# 0              0         0.895   0.404   -10.241       0.1080      0.218000
# 1              1         0.705   0.549    -8.171       0.1840      0.477000
# 2              2         0.806   0.545   -10.199       0.0569      0.000086
# 3              3         0.765   0.776    -7.991       0.0326      0.033500
# 4              4         0.927   0.525    -8.256       0.0667      0.274000
# ...          ...           ...     ...       ...          ...           ...
# 1314         395         0.528   0.826    -6.898       0.0366      0.216000
# 1315         396         0.901   0.654   -12.354       0.0405      0.286000
# 1316         397         0.619   0.868    -6.571       0.0363      0.009230
# 1317         398         0.196   0.313   -17.095       0.0437      0.953000
# 1318         399         0.547   0.764   -12.552       0.0419      0.000523
#
#       instrumentalness  liveness  valence    tempo                      id  \
# 0             0.316000    0.0974   0.1760  112.993  3q6ql0KuUMPBolEfd8LhbE
# 1             0.479000    0.0888   0.2740   84.014  6LRY3cFPXnM9WXKXrKPKJr
# 2             0.865000    0.1030   0.6720  124.998  72heTYSB1VaSn8LBR7JKS6
# 3             0.617000    0.1340   0.7080  104.015  5nLAheg0AIva7wue6gUiNN
# 4             0.238000    0.0672   0.7780  118.023  1vMGIZbIkpaLSagdF2ygcV
# ...                ...       ...      ...      ...                     ...
# 1314          0.438000    0.0975   0.1820  123.012  7EMoSEOUoS90lQdXll2mak
# 1315          0.010100    0.0701   0.9040  138.977  4ZTSygIiwgD9jJE2dc4w78
# 1316          0.495000    0.3400   0.7450  118.836  0PvaYr8WfHQa15r7TfmgDN
# 1317          0.963000    0.0864   0.0747  143.676  4i6HWnWWkpoUyUi0SZ3lZ8
# 1318          0.000018    0.2850   0.7220  117.722  2ItPID4dgSL1t1ZbZCrg5S
#
#       duration_ms
# 0          284602
# 1          174286
# 2          323200
# 3          234519
# 4          198305
# ...           ...
# 1314       299746
# 1315       388160
# 1316       236640
# 1317       305500
# 1318       239493
#
# [1319 rows x 12 columns]

# %%
spotipy.drop(columns=['Unnamed: 0'], inplace=True)

# %%
spotipy.drop_duplicates(inplace=True)

# %%
spotipy
# Out:
#       danceability  energy  loudness  speechiness  acousticness  \
# 0            0.895   0.404   -10.241       0.1080      0.218000
# 1            0.705   0.549    -8.171       0.1840      0.477000
# 2            0.806   0.545   -10.199       0.0569      0.000086
# 3            0.765   0.776    -7.991       0.0326      0.033500
# 4            0.927   0.525    -8.256       0.0667      0.274000
# ...            ...     ...       ...          ...           ...
# 1313         0.580   0.859    -7.188       0.0772      0.055200
# 1314         0.528   0.826    -6.898       0.0366      0.216000
# 1315         0.901   0.654   -12.354       0.0405      0.286000
# 1317         0.196   0.313   -17.095       0.0437      0.953000
# 1318         0.547   0.764   -12.552       0.0419      0.000523
#
#       instrumentalness  liveness  valence    tempo                      id  \
# 0             0.316000    0.0974   0.1760  112.993  3q6ql0KuUMPBolEfd8LhbE
# 1             0.479000    0.0888   0.2740   84.014  6LRY3cFPXnM9WXKXrKPKJr
# 2             0.865000    0.1030   0.6720  124.998  72heTYSB1VaSn8LBR7JKS6
# 3             0.617000    0.1340   0.7080  104.015  5nLAheg0AIva7wue6gUiNN
# 4             0.238000    0.0672   0.7780  118.023  1vMGIZbIkpaLSagdF2ygcV
# ...                ...       ...      ...      ...                     ...
# 1313          0.033800    0.3580   0.7340  164.807  32w5cY5h7jY5oovSLAIBqo
# 1314          0.438000    0.0975   0.1820  123.012  7EMoSEOUoS90lQdXll2mak
# 1315          0.010100    0.0701   0.9040  138.977  4ZTSygIiwgD9jJE2dc4w78
# 1317          0.963000    0.0864   0.0747  143.676  4i6HWnWWkpoUyUi0SZ3lZ8
# 1318          0.000018    0.2850   0.7220  117.722  2ItPID4dgSL1t1ZbZCrg5S
#
#       duration_ms
# 0          284602
# 1          174286
# 2          323200
# 3          234519
# 4          198305
# ...           ...
# 1313       315848
# 1314       299746
# 1315       388160
# 1317       305500
# 1318       239493
#
# [1233 rows x 11 columns]

# %%
scaler = StandardScaler()
X_normalized = scaler.fit_transform(spotipy[['danceability','energy','loudness','speechiness','acousticness','instrumentalness','liveness','valence','tempo','duration_ms']])

# %%
df_normalized = pd.DataFrame(X_normalized, columns=['danceability','energy','loudness','speechiness','acousticness','instrumentalness','liveness','valence','tempo','duration_ms'])

# %%
import pickle

with open("scaler.pickle", "wb") as f: #saves the model in dir and file name given
    pickle.dump(scaler,f)

# %%
pca = PCA(n_components=10)

# %%
pca.fit(X_normalized)
# Out:
# PCA(n_components=10)

# %%
pca.explained_variance_ratio_
# Out:
# array([0.25409713, 0.14132796, 0.12991417, 0.10102498, 0.0949208 ,
#        0.08175178, 0.07437159, 0.05411408, 0.04583944, 0.02263807])

# %%
np.cumsum(pca.explained_variance_ratio_)
# Out:
# array([0.25409713, 0.39542509, 0.52533926, 0.62636424, 0.72128504,
#        0.80303682, 0.87740841, 0.93152249, 0.97736193, 1.        ])

# %%
X_pca = pca.transform(X_normalized)

# %%
K = range(1, 11) #range of the clusters
inertia = []

for k in K: #for every data in set build a inertia
    print("Training a K-Means model with {} clusters! ".format(k))
    print()
    kmeans = KMeans(n_clusters=k,
                    random_state=1234)
    kmeans.fit(df_normalized)
    inertia.append(kmeans.inertia_)

import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

plt.figure(figsize=(16,8))
plt.plot(K, inertia, 'bx-')
plt.xlabel('k')
plt.ylabel('inertia')
plt.xticks(np.arange(min(K), max(K)+1, 1.0)) #changing the scale
plt.title('Elbow Method showing the optimal k')
# Out:
# Training a K-Means model with 1 clusters!
#
# Training a K-Means model with 2 clusters!
#
# Training a K-Means model with 3 clusters!
#
# Training a K-Means model with 4 clusters!
#
# Training a K-Means model with 5 clusters!
#
# Training a K-Means model with 6 clusters!
#
# Training a K-Means model with 7 clusters!
#
# Training a K-Means model with 8 clusters!
#
# Training a K-Means model with 9 clusters!
#
# Training a K-Means model with 10 clusters!
# Text(0.5, 1.0, 'Elbow Method showing the optimal k')

# %%
kmeans.fit(X_pca)
# Out:
# KMeans(n_clusters=10, random_state=1234)

# %%
cluster_ids = kmeans.predict(X_pca)

# %%
cluster_distances = kmeans.transform(X_pca)

# %%
cluster_ids = KMeans(n_clusters=15, n_init=10).fit_predict(X_normalized)

# %%
for c in np.unique(cluster_ids):
    plt.scatter(X_normalized[cluster_ids == c, 0], X_normalized[cluster_ids == c, 1], marker='.', s=12)

# %%
spotipy["cluster"] = cluster_ids

# %%
df_normalized["cluster"] = cluster_ids

# %%
df_normalized[df_normalized["cluster"] == 13]
# Out:
#       danceability    energy  loudness  speechiness  acousticness  \
# 13        0.609120 -0.498986  0.928653     1.541669     -0.352453
# 32        0.388653  1.720229  0.805599    -0.280253     -0.858238
# 64        1.514196  1.399151  1.613539     0.580099     -0.835546
# 94        0.696147  1.512472  0.669444     2.009802     -0.662041
# 101       1.549007  0.700334  0.457248     1.883279     -0.868750
# 111       1.322738  0.129005  0.439265    -0.430814     -0.584814
# 116      -1.206834  0.336761  0.390968     1.060884      0.555898
# 182      -0.818116  1.134734  0.392253    -0.434610     -0.868308
# 192      -0.470009  0.926978  1.293703    -0.533297     -0.849630
# 193       0.417662 -0.012647 -0.789214     2.060411     -0.636865
# 260      -1.659372  0.624787  0.897568     3.224416     -0.202762
# 263      -1.270654  0.879760  1.261334    -0.375144     -0.867968
# 303       0.342239  0.827821  1.502816     1.402494     -0.816494
# 330       1.432972 -0.055143  1.055046     3.237068     -0.372865
# 364       0.156582  0.114840  1.061468     3.097894     -0.651834
# 383       1.021046  0.799491  0.524041    -0.143608     -0.674288
# 420      -1.647769  0.275379  0.766294    -0.365023     -0.406886
# 451      -1.839227  1.115847  0.723392    -0.047452     -0.865076
# 467      -0.232137  0.676726  0.744715    -0.568724      1.202291
# 484      -1.775408  0.176222  0.373756    -0.387797      1.634353
# 511      -0.992169 -0.040978  0.381720    -0.558602      1.491466
# 540       0.852794 -1.155306 -0.022635    -0.289109      0.868888
# 556       1.467782 -0.404551 -0.107411     2.984024     -0.502144
# 571       0.475679 -1.193080 -0.066821     1.744105      1.192084
# 577      -1.021178 -1.183637 -0.903790    -0.624393      1.110435
# 590       1.032649  0.190387  0.536115    -0.244826      1.124043
# 611       0.475679 -0.078751 -0.880156    -0.406775     -0.835546
# 627      -1.607156 -0.617029 -0.191930    -0.575050     -0.752876
# 646      -1.398293 -0.055143 -0.361225    -0.219522      0.589919
# 662       0.121771  0.426474  0.443118    -0.339718      0.008166
# 686      -1.282257 -0.154299  0.240684     0.270120      1.535693
# 695      -1.079195  0.525630  0.572337    -0.534563     -0.338844
# 713       0.040547 -0.555646  0.548960    -0.548480      0.838270
# 722      -1.102402  0.313152  0.294375     0.415620      0.600125
# 724      -0.371379 -0.947550 -0.182682    -0.524441     -0.226576
# 764      -0.800710  0.738108  0.652746    -0.502932      1.283940
# 773      -1.224240 -0.470655  0.064967     1.250668      1.358786
# 788      -0.615054  0.960030  1.073029    -0.534563     -0.871635
# 795      -0.702080 -1.150585 -0.061169    -0.615537      1.532291
# 810      -1.711588 -1.211967 -0.275935    -0.601619      0.868888
# 850      -1.195231  0.044014  0.232463    -0.320740      0.157857
# 882      -2.164126  0.591735  0.372729    -0.200544     -0.871461
# 918       1.235711 -0.848394  0.315184    -0.282783     -0.855822
# 947       0.342239  0.535074  0.877787    -0.304292     -0.671566
# 948      -1.166222  1.554968  0.917349    -0.330862     -0.871101
# 949      -0.678873  1.361377  0.248391    -0.515584     -0.795061
# 952      -2.808123  1.167786  0.785048     0.744578     -0.529360
# 963      -0.986367  1.597464 -0.194242    -0.385266     -0.856264
# 1000     -0.284353  1.554968  1.087415    -0.327066     -0.318432
# 1004     -1.264852  1.498307  1.356899    -0.368818     -0.832144
# 1086     -1.299663 -0.366777  0.582870    -0.597824     -0.362659
# 1096     -0.458406  1.904376  0.490901     1.465756     -0.810030
# 1154      0.887605 -0.546203  0.546905    -0.447262     -0.547391
# 1209      0.173987  1.092238  0.374784    -0.396653     -0.792340
#
#       instrumentalness  liveness   valence     tempo  duration_ms  cluster
# 13           -0.862017  4.981657  1.339717 -0.899841    -1.396022       13
# 32            0.756279  4.989154  1.549726  0.293041    -1.010299       13
# 64            0.483657  3.827075  1.114436  0.000733     0.751703       13
# 94            0.341546  3.302265 -0.802369  0.115737    -0.002037       13
# 101           0.135630  4.284409  1.400811  0.075591     1.527672       13
# 111           0.071825  3.632146  0.106395 -0.186616     0.490109       13
# 116          -0.862048  1.757825 -0.031065  0.738699    -1.174529       13
# 182          -0.799693  2.012733  0.854789 -0.602698     0.296664       13
# 192          -0.836961  2.679991  0.751694  0.670326    -0.240267       13
# 193          -0.862028  5.603931  0.671509 -0.783301     0.151827       13
# 260          -0.862048  3.167314 -0.978012 -1.293058     0.572521       13
# 263          -0.090588  3.617151  1.419902  0.355303    -0.295205       13
# 303          -0.856682  3.617151 -0.046338 -0.747727    -0.844339       13
# 330          -0.862048  4.171950  0.770785  0.375620    -0.667079       13
# 364           0.242939  3.849567  1.038069  4.049664    -0.626882       13
# 383          -0.849954  3.519686 -0.412899  0.300838    -0.826710       13
# 420          -0.860815  1.825301  0.045302  0.347469     0.897645       13
# 451           1.852564  6.046271 -1.512579  0.140065    -1.470638       13
# 467          -0.634960  2.942396  0.969339 -0.702858    -1.263058       13
# 484          -0.087687  3.489697 -0.118887  2.134711    -0.036648       13
# 511          -0.862048  2.627510 -0.122705 -1.721210     0.970286       13
# 540          -0.860650  2.342613 -0.328895  0.153409    -0.218740       13
# 556          -0.825795  3.744605  0.598960 -1.082767     0.140495       13
# 571          -0.499520  4.239426 -0.592360 -0.945310     1.149692       13
# 577           1.916369  3.977021 -1.497306  0.368385     0.799228       13
# 590          -0.859861  3.917042  1.645184 -0.429930    -0.274963       13
# 611          -0.861613  2.912407  0.759330  0.037206     2.605358       13
# 627          -0.855435  3.977021 -1.306389 -0.258924     2.712833       13
# 646           1.881567  4.066988 -1.000922  1.947961    -0.631799       13
# 662          -0.862026  2.537542  0.946429  0.474880     0.607525       13
# 686          -0.862048  3.924540 -0.832916 -0.010175    -0.998405       13
# 695          -0.861918  3.062352 -0.344169 -1.496638    -0.687979       13
# 713          -0.730088  2.522548  0.205672 -0.458194    -0.725394       13
# 722           1.884467  2.949893  0.293493 -0.977135     0.281350       13
# 724           1.292821  2.507553 -0.836734 -0.959667     0.526079       13
# 764          -0.820575  3.707119  1.274806  0.218408    -1.292252       13
# 773          -0.861971  2.852428  0.709692 -1.929776    -1.506471       13
# 788          -0.044184  2.889915 -0.577087 -0.663311    -0.924914       13
# 795          -0.829855  4.126966 -1.581309 -0.160189    -0.194813       13
# 810          -0.857872  3.797086 -0.894009 -0.790385    -0.525598       13
# 850          -0.070286  3.482200 -1.724497 -2.117988    -0.199561       13
# 882          -0.572025  3.497195 -0.989467  1.363234    -0.706479       13
# 918          -0.406712  1.900273 -0.275439  0.413030    -0.388811       13
# 947          -0.836352  5.371515  0.957884 -0.785437    -0.780480       13
# 948          -0.862001  4.621787 -0.279257  1.422348    -0.016162       13
# 949          -0.412513  1.952754 -1.619493  0.028060    -0.815452       13
# 952          -0.487919  2.844931 -0.279257  1.514636    -0.061425       13
# 963           1.603145  2.380100  0.629507 -1.010721    -1.518726       13
# 1000         -0.862048  2.350110  1.358809  0.718644    -1.501086       13
# 1004         -0.859916  3.984518 -0.424354 -0.692775    -0.394471       13
# 1086         -0.862048  3.084844 -1.378938 -1.236006    -0.007613       13
# 1096         -0.861143  4.299404 -0.359442  0.581412     0.591361       13
# 1154         -0.762570  2.162678  0.759330  1.471341    -0.309797       13
# 1209          0.196535  3.347249  0.350768 -0.860744    -0.329763       13

# %%
spotipy[spotipy["cluster"] == 13]
# Out:
#       danceability  energy  loudness  speechiness  acousticness  \
# 13           0.749   0.477    -6.060       0.1980      0.153000
# 32           0.711   0.947    -6.539       0.0540      0.004330
# 66           0.905   0.879    -3.394       0.1220      0.011000
# 98           0.764   0.903    -7.069       0.2350      0.062000
# 105          0.911   0.731    -7.895       0.2250      0.001240
# 115          0.872   0.610    -7.965       0.0421      0.084700
# 120          0.436   0.654    -8.153       0.1600      0.420000
# 186          0.503   0.823    -8.148       0.0418      0.001370
# 198          0.563   0.779    -4.639       0.0340      0.006860
# 199          0.716   0.580   -12.747       0.2390      0.069400
# 266          0.358   0.715    -6.181       0.3310      0.197000
# 269          0.425   0.769    -4.765       0.0465      0.001470
# 309          0.703   0.758    -3.825       0.1870      0.016600
# 336          0.891   0.571    -5.568       0.3320      0.147000
# 370          0.671   0.607    -5.543       0.3210      0.065000
# 389          0.820   0.752    -7.635       0.0648      0.058400
# 426          0.360   0.641    -6.692       0.0473      0.137000
# 458          0.327   0.819    -6.859       0.0724      0.002320
# 474          0.604   0.726    -6.776       0.0312      0.610000
# 492          0.338   0.620    -8.220       0.0455      0.737000
# 519          0.473   0.574    -8.189       0.0320      0.695000
# 548          0.791   0.338    -9.763       0.0533      0.512000
# 566          0.897   0.497   -10.093       0.3120      0.109000
# 581          0.726   0.330    -9.935       0.2140      0.607000
# 588          0.468   0.332   -13.193       0.0268      0.583000
# 602          0.822   0.623    -7.588       0.0568      0.587000
# 625          0.726   0.566   -13.101       0.0440      0.011000
# 641          0.367   0.452   -10.422       0.0307      0.035300
# 660          0.403   0.571   -11.081       0.0588      0.430000
# 676          0.665   0.673    -7.950       0.0493      0.259000
# 700          0.423   0.550    -8.738       0.0975      0.708000
# 709          0.458   0.694    -7.447       0.0339      0.157000
# 727          0.651   0.465    -7.538       0.0328      0.503000
# 736          0.454   0.649    -8.529       0.1090      0.433000
# 739          0.580   0.382   -10.386       0.0347      0.190000
# 781          0.506   0.739    -7.134       0.0364      0.634000
# 792          0.433   0.483    -9.422       0.1750      0.656000
# 807          0.538   0.786    -5.498       0.0339      0.000392
# 814          0.523   0.339    -9.913       0.0275      0.707000
# 830          0.349   0.326   -10.749       0.0286      0.512000
# 871          0.438   0.592    -8.770       0.0508      0.303000
# 904          0.271   0.708    -8.224       0.0603      0.000443
# 942          0.857   0.403    -8.448       0.0538      0.005040
# 977          0.703   0.696    -6.258       0.0521      0.059200
# 981          0.443   0.912    -6.104       0.0500      0.000549
# 982          0.527   0.871    -8.708       0.0354      0.022900
# 985          0.160   0.830    -6.619       0.1350      0.101000
# 997          0.474   0.921   -10.431       0.0457      0.004910
# 1044         0.595   0.912    -5.442       0.0503      0.163000
# 1050         0.426   0.900    -4.393       0.0470      0.012000
# 1151         0.420   0.505    -7.406       0.0289      0.150000
# 1165         0.565   0.986    -7.764       0.1920      0.018500
# 1233         0.797   0.467    -7.546       0.0408      0.095700
# 1291         0.674   0.814    -8.216       0.0448      0.023700
#
#       instrumentalness  liveness  valence    tempo                      id  \
# 13            0.000011     0.823   0.8820   95.968  1pur8kv69XmZqA3uoMEYnH
# 32            0.558000     0.824   0.9370  127.791  0jwYW50Xctkw18syigz5il
# 66            0.464000     0.669   0.8230  119.993  1isB5wVstnD0zNAmCPf6Me
# 98            0.415000     0.599   0.3210  123.061  3c2YJsVKnieV2fbDD0MVPX
# 105           0.344000     0.730   0.8980  121.990  58EJZu0JmhgFp6KfHCS6ys
# 115           0.322000     0.643   0.5590  114.995  4Vldw0eUgCbhgyxAWY6JMk
# 120           0.000000     0.393   0.5230  139.680  2tHdQjwO5zN86MLF7ZtU1X
# 186           0.021500     0.427   0.7550  103.895  7x0D3rgwHOxexlTZ5W87vi
# 198           0.008650     0.516   0.7280  137.856  4NYQ1giz24QOgb2MYajhBi
# 199           0.000007     0.906   0.7070   99.077  1VzhfMEGIIkn5hFITMJzW1
# 266           0.000000     0.581   0.2750   85.478  0NjW4SKY3gbfl2orl1p8hr
# 269           0.266000     0.641   0.9030  129.452  5aLD8CPaEu3Cj9ZcAqWWA6
# 309           0.001850     0.641   0.5190  100.026  0dJ0pX1MohcF33LpFssliC
# 336           0.000000     0.715   0.7330  129.994  1LzvuqP3L5Q7G61kUBgfCJ
# 370           0.381000     0.672   0.8030  228.008  3oJzE5dSRl51xxzLeih0sy
# 389           0.004170     0.628   0.4230  127.999  4hceSKjrkDTO0nMKFcb3sj
# 426           0.000425     0.402   0.5430  129.243  4NLB0Nfa2b2hGyu9x0EWYc
# 458           0.936000     0.965   0.1350  123.710  5AWNBhQ1vOXHMPS8w1djig
# 474           0.078300     0.551   0.7850  101.223  7uTG1u7UjDRZe0wEcDR2Xj
# 492           0.267000     0.624   0.5000  176.922  7eYYxblNEZKKeTT0HBQbXO
# 519           0.000000     0.509   0.4990   74.056  0f5N14nB8xi0p3o4BlVvbx
# 548           0.000482     0.471   0.4450  124.066  3VtgKyNdd9D7T3u9FZbrsX
# 566           0.012500     0.658   0.6880   91.088  42uCM9saw5B3bCjEFLROlE
# 581           0.125000     0.724   0.3760   94.755  6FTBZdL2sXXUSBXMwrQTut
# 588           0.958000     0.689   0.1390  129.801  7E2NpVcD3i6AIm3uyd343i
# 602           0.000754     0.681   0.9620  108.504  07rdGJ1AqErux9b45aE7C9
# 625           0.000150     0.547   0.7300  120.966  2ldalh6d2MrsAFaZG9H3P4
# 641           0.002280     0.689   0.1890  113.066  54X78diSLoUDI3joC2bjMz
# 660           0.946000     0.701   0.2690  171.940  6gg9MlZzuDBRaLaB3u6ccn
# 676           0.000008     0.497   0.7790  132.642  5Wj1rJnCLpMHdLaxsFtJLs
# 700           0.000000     0.682   0.3130  119.702  6O5PIO5pAWxdoxvaUFQ02G
# 709           0.000045     0.567   0.4410   80.047  4RfIfFS2D4E9tVjuHFlAJF
# 727           0.045500     0.495   0.5850  107.750  77iRifbhkJGvGBBRNykUwN
# 736           0.947000     0.552   0.6080   93.906  4oyhSzJeJUl2NwExDax1Gl
# 739           0.743000     0.493   0.3120   94.372  0OnQj8a27DzuNnTXSgOtq6
# 781           0.014300     0.653   0.8650  125.800  5yZWNT9HcHJW4besDfCgSz
# 792           0.000026     0.539   0.7170   68.492  2X9H5BokS1u5O46YpNYNsZ
# 807           0.282000     0.544   0.3800  102.278  0k01ZymzoRgA4473T3yKSD
# 814           0.011100     0.709   0.1170  115.700  2kMVxFh1y5gow2hBtqGO4m
# 830           0.001440     0.665   0.2970   98.888  2ACjOtICHXrAlP3ijVMSvb
# 871           0.273000     0.623   0.0795   63.471  5zlrBXbVh4LdCC4Ekj8EtI
# 904           0.100000     0.625   0.2720  156.341  0XgWyz9dYcbCIlu3OrgnIO
# 942           0.157000     0.412   0.4590  130.992  2L3XwBLk2LnYHPqPWGdupU
# 977           0.008860     0.875   0.7820   99.020  1SC55hrlEAjJ7znmzpbLmt
# 981           0.000016     0.775   0.4580  157.918  1tbL1iLdlz8fLqopGAL6zZ
# 982           0.155000     0.419   0.1070  120.722  672N8DGGTOLCOgWe0koX5g
# 985           0.129000     0.538   0.4580  160.380  5pZjTg3p3ekLIltKfe9iQQ
# 997           0.850000     0.476   0.6960   93.010  1aXV8GrmQLvgoFtBPERP7E
# 1044          0.000000     0.472   0.8870  139.145  5aXTeyNGhtc6lODlY5E1MN
# 1050          0.000735     0.690   0.4200  101.492  34tFidHrETMAjsiK87WVVW
# 1151          0.000000     0.570   0.1700   87.000  0ftgoTIc4IMEUi9w4lJ3IS
# 1165          0.000312     0.732   0.4370  135.484  0SNjkOj4k9b8FRK5nfPYR0
# 1233          0.034300     0.447   0.7300  159.225  6SVl0bOoxhzqEYgnmAYWNt
# 1291          0.365000     0.605   0.6230   97.011  6eQ0yqG2lN2GK1xuf6qAZ9
#
#       duration_ms  cluster
# 13         133893       13
# 32         170213       13
# 66         336125       13
# 98         265152       13
# 105        409191       13
# 115        311493       13
# 120        154749       13
# 186        293278       13
# 198        242720       13
# 199        279640       13
# 266        319253       13
# 269        237547       13
# 309        185840       13
# 336        202531       13
# 370        206316       13
# 389        187500       13
# 426        349867       13
# 458        126867       13
# 474        146413       13
# 492        261893       13
# 519        356707       13
# 548        244747       13
# 566        278573       13
# 581        373600       13
# 588        340600       13
# 602        239453       13
# 625        510667       13
# 641        520787       13
# 660        205853       13
# 676        322549       13
# 700        171333       13
# 709        200563       13
# 727        197040       13
# 736        291836       13
# 739        314880       13
# 781        143664       13
# 792        123493       13
# 807        178253       13
# 814        247000       13
# 830        215853       13
# 871        246553       13
# 904        198821       13
# 942        228733       13
# 977        191853       13
# 981        263822       13
# 982        188560       13
# 985        259560       13
# 997        122339       13
# 1044       124000       13
# 1050       228200       13
# 1151       264627       13
# 1165       321027       13
# 1233       236173       13
# 1291       234293       13

# %%
spotipy
# Out:
#       danceability  energy  loudness  speechiness  acousticness  \
# 0            0.895   0.404   -10.241       0.1080      0.218000
# 1            0.705   0.549    -8.171       0.1840      0.477000
# 2            0.806   0.545   -10.199       0.0569      0.000086
# 3            0.765   0.776    -7.991       0.0326      0.033500
# 4            0.927   0.525    -8.256       0.0667      0.274000
# ...            ...     ...       ...          ...           ...
# 1313         0.580   0.859    -7.188       0.0772      0.055200
# 1314         0.528   0.826    -6.898       0.0366      0.216000
# 1315         0.901   0.654   -12.354       0.0405      0.286000
# 1317         0.196   0.313   -17.095       0.0437      0.953000
# 1318         0.547   0.764   -12.552       0.0419      0.000523
#
#       instrumentalness  liveness  valence    tempo                      id  \
# 0             0.316000    0.0974   0.1760  112.993  3q6ql0KuUMPBolEfd8LhbE
# 1             0.479000    0.0888   0.2740   84.014  6LRY3cFPXnM9WXKXrKPKJr
# 2             0.865000    0.1030   0.6720  124.998  72heTYSB1VaSn8LBR7JKS6
# 3             0.617000    0.1340   0.7080  104.015  5nLAheg0AIva7wue6gUiNN
# 4             0.238000    0.0672   0.7780  118.023  1vMGIZbIkpaLSagdF2ygcV
# ...                ...       ...      ...      ...                     ...
# 1313          0.033800    0.3580   0.7340  164.807  32w5cY5h7jY5oovSLAIBqo
# 1314          0.438000    0.0975   0.1820  123.012  7EMoSEOUoS90lQdXll2mak
# 1315          0.010100    0.0701   0.9040  138.977  4ZTSygIiwgD9jJE2dc4w78
# 1317          0.963000    0.0864   0.0747  143.676  4i6HWnWWkpoUyUi0SZ3lZ8
# 1318          0.000018    0.2850   0.7220  117.722  2ItPID4dgSL1t1ZbZCrg5S
#
#       duration_ms  cluster
# 0          284602       12
# 1          174286        3
# 2          323200        1
# 3          234519        6
# 4          198305       12
# ...           ...      ...
# 1313       315848        7
# 1314       299746        2
# 1315       388160       12
# 1317       305500       10
# 1318       239493       11
#
# [1233 rows x 12 columns]

# %%
df_normalized
# Out:
#       danceability    energy  loudness  speechiness  acousticness  \
# 0         1.456179 -0.843672 -0.145432     0.402968     -0.131319
# 1         0.353842 -0.159021  0.386344     1.364538      0.749816
# 2         0.939821 -0.177908 -0.134642    -0.243561     -0.872677
# 3         0.701948  0.912812  0.432586    -0.551010     -0.758999
# 4         1.641835 -0.272342  0.364508    -0.119569      0.059197
# ...            ...       ...       ...          ...           ...
# 1228     -0.371379  1.304716  0.638873     0.013279     -0.685175
# 1229     -0.673071  1.148899  0.713373    -0.500401     -0.138123
# 1230      1.490989  0.336761 -0.688254    -0.451058      0.100022
# 1231     -2.599259 -1.273350 -1.906200    -0.410571      2.369199
# 1232     -0.562838  0.856152 -0.739119    -0.433345     -0.871189
#
#       instrumentalness  liveness   valence     tempo  duration_ms  cluster
# 0             0.054424 -0.458372 -1.356028 -0.261661     0.204524       12
# 1             0.527161 -0.522848 -0.981831 -1.347936    -0.967044        3
# 2             1.646648 -0.416387  0.537867  0.188345     0.614439        1
# 3             0.927392 -0.183971  0.675327 -0.598200    -0.327363        6
# 4            -0.171794 -0.684789  0.942610 -0.073112    -0.711959       12
# ...                ...       ...       ...       ...          ...      ...
# 1228         -0.764020  1.495420  0.774604  1.680581     0.536360        7
# 1229          0.408251 -0.457622 -1.333118  0.113900     0.365355        2
# 1230         -0.832756 -0.663047  1.423721  0.712347     1.304321       12
# 1231          1.930870 -0.540842 -1.742825  0.888488     0.426463       10
# 1232         -0.861996  0.948119  0.728784 -0.084395    -0.274539       11
#
# [1233 rows x 11 columns]

# %%
from IPython.display import IFrame

#track_id = "1rfORa9iYmocEsnnZGMVC4"
track_id= '0EFKOoOek7dGXQKuOxGQRE'
IFrame(src="https://open.spotify.com/embed/track/"+track_id+"?utm_source=generator",
       width="320",
       height="80",
       frameborder="0",
       allowtransparency="true",
       allow="encrypted-media",
      )
# Out:
#         <iframe
#             width="320"
#             height="80"
#             src="https://open.spotify.com/embed/track/0EFKOoOek7dGXQKuOxGQRE?utm_source=generator?frameborder=0&allowtransparency=true&allow=encrypted-media"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
#k.means.predict : pour récupérer plus de chansons 
#récupérer les features

# %%
results = sp.search(q="Love yourself",limit=3,market="GB")

# %%
import pprint

pprint.pprint(results)
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=Love+yourself&type=track&market=GB&offset=0&limit=3',
#             'items': [{'album': {'album_type': 'album',
#                                  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1uNFoZAHBGtllmzznpCI3s'},
#                                               'href': 'https://api.spotify.com/v1/artists/1uNFoZAHBGtllmzznpCI3s',
#                                               'id': '1uNFoZAHBGtllmzznpCI3s',
#                                               'name': 'Justin Bieber',
#                                               'type': 'artist',
#                                               'uri': 'spotify:artist:1uNFoZAHBGtllmzznpCI3s'}],
#                                  'external_urls': {'spotify': 'https://open.spotify.com/album/6Fr2rQkZ383FcMqFyT7yPr'},
#                                  'href': 'https://api.spotify.com/v1/albums/6Fr2rQkZ383FcMqFyT7yPr',
#                                  'id': '6Fr2rQkZ383FcMqFyT7yPr',
#                                  'images': [{'height': 640,
#                                              'url': 'https://i.scdn.co/image/ab67616d0000b273f46b9d202509a8f7384b90de',
#                                              'width': 640},
#                                             {'height': 300,
#                                              'url': 'https://i.scdn.co/image/ab67616d00001e02f46b9d202509a8f7384b90de',
#                                              'width': 300},
#                                             {'height': 64,
#                                              'url': 'https://i.scdn.co/image/ab67616d00004851f46b9d202509a8f7384b90de',
#                                              'width': 64}],
#                                  'is_playable': True,
#                                  'name': 'Purpose (Deluxe)',
#                                  'release_date': '2015-11-13',
#                                  'release_date_precision': 'day',
#                                  'total_tracks': 19,
#                                  'type': 'album',
#                                  'uri': 'spotify:album:6Fr2rQkZ383FcMqFyT7yPr'},
#                        'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1uNFoZAHBGtllmzznpCI3s'},
#                                     'href': 'https://api.spotify.com/v1/artists/1uNFoZAHBGtllmzznpCI3s',
#                                     'id': '1uNFoZAHBGtllmzznpCI3s',
#                                     'name': 'Justin Bieber',
#                                     'type': 'artist',
#                                     'uri': 'spotify:artist:1uNFoZAHBGtllmzznpCI3s'}],
#                        'disc_number': 1,
#                        'duration_ms': 233720,
#                        'explicit': False,
#                        'external_ids': {'isrc': 'USUM71516761'},
#                        'external_urls': {'spotify': 'https://open.spotify.com/track/50kpGaPAhYJ3sGmk6vplg0'},
#                        'href': 'https://api.spotify.com/v1/tracks/50kpGaPAhYJ3sGmk6vplg0',
#                        'id': '50kpGaPAhYJ3sGmk6vplg0',
#                        'is_local': False,
#                        'is_playable': True,
#                        'name': 'Love Yourself',
#                        'popularity': 85,
#                        'preview_url': 'https://p.scdn.co/mp3-preview/2be1b6dea766a292352d2cbc5a67dbbb0d9a1b4b?cid=170e2b3ef5314e41b5251874696db293',
#                        'track_number': 5,
#                        'type': 'track',
#                        'uri': 'spotify:track:50kpGaPAhYJ3sGmk6vplg0'},
#                       {'album': {'album_type': 'compilation',
#                                  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#                                               'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#                                               'id': '0LyfQWJT6nXafLPZqxe9Of',
#                                               'name': 'Various Artists',
#                                               'type': 'artist',
#                                               'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#                                  'external_urls': {'spotify': 'https://open.spotify.com/album/4JznLSBNpBkFVIscp9A14g'},
#                                  'href': 'https://api.spotify.com/v1/albums/4JznLSBNpBkFVIscp9A14g',
#                                  'id': '4JznLSBNpBkFVIscp9A14g',
#                                  'images': [{'height': 640,
#                                              'url': 'https://i.scdn.co/image/ab67616d0000b273846ccc011755da305ca741a3',
#                                              'width': 640},
#                                             {'height': 300,
#                                              'url': 'https://i.scdn.co/image/ab67616d00001e02846ccc011755da305ca741a3',
#                                              'width': 300},
#                                             {'height': 64,
#                                              'url': 'https://i.scdn.co/image/ab67616d00004851846ccc011755da305ca741a3',
#                                              'width': 64}],
#                                  'is_playable': True,
#                                  'name': 'Domingos Tranquilos',
#                                  'release_date': '2023-05-19',
#                                  'release_date_precision': 'day',
#                                  'total_tracks': 19,
#                                  'type': 'album',
#                                  'uri': 'spotify:album:4JznLSBNpBkFVIscp9A14g'},
#                        'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1uNFoZAHBGtllmzznpCI3s'},
#                                     'href': 'https://api.spotify.com/v1/artists/1uNFoZAHBGtllmzznpCI3s',
#                                     'id': '1uNFoZAHBGtllmzznpCI3s',
#                                     'name': 'Justin Bieber',
#                                     'type': 'artist',
#                                     'uri': 'spotify:artist:1uNFoZAHBGtllmzznpCI3s'}],
#                        'disc_number': 1,
#                        'duration_ms': 232626,
#                        'explicit': False,
#                        'external_ids': {'isrc': 'USUM71516761'},
#                        'external_urls': {'spotify': 'https://open.spotify.com/track/6OiMu2zPqzguPx0HNE0mcW'},
#                        'href': 'https://api.spotify.com/v1/tracks/6OiMu2zPqzguPx0HNE0mcW',
#                        'id': '6OiMu2zPqzguPx0HNE0mcW',
#                        'is_local': False,
#                        'is_playable': True,
#                        'name': 'Love Yourself',
#                        'popularity': 0,
#                        'preview_url': 'https://p.scdn.co/mp3-preview/1e34e7e4c1dd0a13f1193873ac8f0ee2c7f8d613?cid=170e2b3ef5314e41b5251874696db293',
#                        'track_number': 7,
#                        'type': 'track',
#                        'uri': 'spotify:track:6OiMu2zPqzguPx0HNE0mcW'},
#                       {'album': {'album_type': 'single',
#                                  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7xj1YIDzHU6vkUwP76NEyx'},
#                                               'href': 'https://api.spotify.com/v1/artists/7xj1YIDzHU6vkUwP76NEyx',
#                                               'id': '7xj1YIDzHU6vkUwP76NEyx',
#                                               'name': 'Music Factory',
#                                               'type': 'artist',
#                                               'uri': 'spotify:artist:7xj1YIDzHU6vkUwP76NEyx'}],
#                                  'external_urls': {'spotify': 'https://open.spotify.com/album/4XrTsVioMvXC2witL0cII3'},
#                                  'href': 'https://api.spotify.com/v1/albums/4XrTsVioMvXC2witL0cII3',
#                                  'id': '4XrTsVioMvXC2witL0cII3',
#                                  'images': [{'height': 640,
#                                              'url': 'https://i.scdn.co/image/ab67616d0000b273473232d96c51036d4e2243b5',
#                                              'width': 640},
#                                             {'height': 300,
#                                              'url': 'https://i.scdn.co/image/ab67616d00001e02473232d96c51036d4e2243b5',
#                                              'width': 300},
#                                             {'height': 64,
#                                              'url': 'https://i.scdn.co/image/ab67616d00004851473232d96c51036d4e2243b5',
#                                              'width': 64}],
#                                  'is_playable': True,
#                                  'name': 'Love Yourself (Sped Up Remix)',
#                                  'release_date': '2023-03-29',
#                                  'release_date_precision': 'day',
#                                  'total_tracks': 1,
#                                  'type': 'album',
#                                  'uri': 'spotify:album:4XrTsVioMvXC2witL0cII3'},
#                        'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7xj1YIDzHU6vkUwP76NEyx'},
#                                     'href': 'https://api.spotify.com/v1/artists/7xj1YIDzHU6vkUwP76NEyx',
#                                     'id': '7xj1YIDzHU6vkUwP76NEyx',
#                                     'name': 'Music Factory',
#                                     'type': 'artist',
#                                     'uri': 'spotify:artist:7xj1YIDzHU6vkUwP76NEyx'}],
#                        'disc_number': 1,
#                        'duration_ms': 178303,
#                        'explicit': False,
#                        'external_ids': {'isrc': 'ARIXB2304444'},
#                        'external_urls': {'spotify': 'https://open.spotify.com/track/7lnIqjb7ft7W3gI1obGGZX'},
#                        'href': 'https://api.spotify.com/v1/tracks/7lnIqjb7ft7W3gI1obGGZX',
#                        'id': '7lnIqjb7ft7W3gI1obGGZX',
#                        'is_local': False,
#                        'is_playable': True,
#                        'name': 'Love Yourself (Sped Up) - Remix',
#                        'popularity': 41,
#                        'preview_url': 'https://p.scdn.co/mp3-preview/b0d66ac7db0b960cc81b0313696ce8a8f754072f?cid=170e2b3ef5314e41b5251874696db293',
#                        'track_number': 1,
#                        'type': 'track',
#                        'uri': 'spotify:track:7lnIqjb7ft7W3gI1obGGZX'}],
#             'limit': 3,
#             'next': 'https://api.spotify.com/v1/search?query=Love+yourself&type=track&market=GB&offset=3&limit=3',
#             'offset': 0,
#             'previous': None,
#             'total': 1000}}

# %%
with open("model.pickle", "wb") as f: #saves the model in dir and file name given
    pickle.dump(kmeans,f)
