# %% [markdown]
# # Lab | Matplotlib & Seaborn
#
# #### Import all the necessary libraries here:

# %%
# Libraries
import numpy as np

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import math
import seaborn as sns

# makes sure charts appear in the notebook rather than a popup window
# %matplotlib inline

# %% [markdown]
# ## Challenge 1
#
# #### The data we will use in this challenge is:

# %%
x = np.arange(0,100)
y = x*2
z = x**2

# %% [markdown]
# #### Plot (x, y) and (x, z).
# There are 2 ways of doing this. Do in both ways.
#
# **Hint**: Check out the nrows, ncols and index arguments of subplots.
#
# Also, play around with the linewidth and style. Use the ones you're most happy with.

# %%
plt.plot(x,y,z)
plt.show()

# %%
fig,(ax1, ax2, ax3) = plt.subplots(nrows=1, ncols=3, sharey=True, figsize=(9,6))
ax1.set_title("Example Line Chart")
ax1.plot(x,y, z)

# %% [markdown]
# #### Use plt.subplots(nrows=1, ncols=2) to create the plot.

# %%
fig,(ax1, ax2) = plt.subplots(nrows=1, ncols=2, sharey=True, figsize=(9,6))
ax1.plot(x,y)
ax2.bar(x,z)
# Out:
# <BarContainer object of 100 artists>

# %% [markdown]
# #### Use your previous code but now, resize your plot.
# **Hint**: Add the figsize argument in plt.subplots().
#
# If you want, try to add a title to the plot or even axes labels. You can also play with the fontweight and fontsize of the titles and labels.

# %%
fig,(ax1, ax2) = plt.subplots(nrows=1, ncols=2, sharey=True, figsize=(15,7))
ax1.plot(x,y)
ax2.bar(x,z)
ax1.set(xlabel="X", ylabel="Y", title="Line Chart")
ax2.set(xlabel="X", ylabel="Z", title="Bar Chart")
# Out:
# [Text(0.5, 0, 'X'), Text(0, 0.5, 'Z'), Text(0.5, 1.0, 'Bar Chart')]

# %% [markdown]
# #### Now you will have to plot both $y=x^2$ and $y=e^x$ in the same plot. Create two subplots and use a normal scale in the first one and a logarithmic scale in the second one.
# **Hint**: Use `set_xscale` and `set_yscale`.

# %%
y1 = x**2
y2= np.exp(x)

# %%
fig,(ax1) = plt.subplots(nrows=1, ncols=1, sharey=True, figsize=(15,7))
ax1.plot(x, y1, color='red')
ax2= ax1.twinx()
ax2.plot(x, y2)
#ax2.set_xscale('log')
ax2.set_yscale('log')
#ax1.set(xlabel="X", ylabel="Y", title="Line Chart Normal Scale")
#ax2.set(xlabel="X", ylabel="Y", title="Line Chart Logarithmic scale")

# %% [markdown]
# #### As a bonus challenge, try to add a legend to the plot.

# %%
# your code here

# %% [markdown]
# ## Challenge 2
# #### Import the `Fitbit2` dataset and store it in a variable called `fitbit`. You can find the dataset in Ironhack's database:
# * db: `fitbit`
# * table: `fitbit2`

# %%
fitbit = pd.read_csv('Fitbit2.csv')

# %%
df = pd.DataFrame(fitbit)

# %%
# Out:
#            Date  Calorie burned  Steps  Distance  Floors  Minutes Sedentary  \
# 0    2015-05-08            1934    905      0.65       0              1.355
# 1    2015-05-09            3631  18925     14.11       4            611.000
# 2    2015-05-10            3204  14228     10.57       1            602.000
# 3    2015-05-11            2673   6756      5.02       8            749.000
# 4    2015-05-12            2495    502      3.73       1            876.000
# ..          ...             ...    ...       ...     ...                ...
# 362  2016-05-03            3796  18588     14.13      16            599.000
# 363  2016-05-04            3525  16382     12.39      16            684.000
# 364  2016-05-05            3649  21913     16.40      19            701.000
# 365  2016-05-06            3539  19023     14.79      15            575.000
# 366  2016-05-07             304   9526      7.08       2            564.000
#
# ...

# %% [markdown]
# #### From the Fitbit data, we want to visually understand:
#
# How the average number of steps change by month. Use the appropriate visualization to show the median steps by month. Is Fitbitter more active on weekend or workdays? All plots must be in the same jupyter notebook cell.
#
# **Hints**:
#
# * Use Months_encoded and Week_or Weekend columns.
# * Use matplolib.pyplot object oriented API.
# * Set your size figure to 12,4
# * Explore plt.sca
# * Explore plt.xticks
# * Save your figures in a folder called `figures` in your repo.

# %%
median_steps_month = df.groupby("Months_encoded")['Steps'].median()
#median_steps_month = pd.DataFrame(median_steps_month)

# %%
median_steps_week = df.groupby("Work_or_Weekend")['Steps'].median()

# %%
median_steps_week
# Out:
# Work_or_Weekend
# 0     9998.0
# 1    10445.5
# Name: Steps, dtype: float64

# %%
# MEDIAN STEPS BY MONTH_ENCODED
median_steps_month.plot(x='Months_encoded', y='Steps', kind='bar', plt.sca)
plt.show()

# MEDIAN STEPS BY WORK_OR_WEEKEND
median_steps_week.plot(x='Work', y='Steps', kind='bar')

x= fitbit['Minutes Sedentary']
y= fitbit['Steps']

plt.scatter(x,y)
plt.title("Minutes Very active vs Steps")
plt.xlabel('Minutes Sedentary')
plt.ylabel('Steps')
plt.show
# Out:
# <AxesSubplot:xlabel='Work_or_Weekend'>

# %% [markdown]
# #### Write a loop to plot 3 scatter plots of the following features:
#
# * Minutes Lightly Active vs Steps
# * Minutes Very Active vs Steps
# * Minutes Sedentary vs Steps

# %%
for i in ['Minutes Lightly Active', 'Minutes Fairly Active', 'Minutes Very Active']:
    df.plot(x=i, y="Steps", kind='scatter', title=i)
plt.show()

# %% [markdown]
# ## Challenge 3
#
# #### Import the `titanic` dataset and store it in a variable called `titanic`. You can find the dataset in Ironhack's database:
# * db: `titanic`
# * table: `titanic`

# %%
titanic = pd.read_csv('titanic.csv')

# %% [markdown]
# #### Explore the titanic dataset using Pandas dtypes.

# %%
titanic.dtypes
# Out:
# PassengerId      int64
# Survived       float64
# Pclass           int64
# Name            object
# Gender          object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# #### What are your numerical variables? What are your categorical variables?
# **Hint**: Use Pandas select_dtypes.

# %%
# NUMERICAL VARIABLES
titanic.select_dtypes(include=['float64','int64'])
# Out:
#       PassengerId  Survived  Pclass        Age  SibSp  Parch      Fare
# 0               1       0.0       3  22.000000      1      0    7.2500
# 1               2       1.0       1  38.000000      1      0   71.2833
# 2               3       1.0       3  26.000000      0      0    7.9250
# 3               4       1.0       1  35.000000      1      0   53.1000
# 4               5       0.0       3  35.000000      0      0    8.0500
# ...           ...       ...     ...        ...    ...    ...       ...
# 1304         1305       NaN       3  29.513190      0      0    8.0500
# 1305         1306       NaN       1  39.000000      0      0  108.9000
# 1306         1307       NaN       3  38.500000      0      0    7.2500
# 1307         1308       NaN       3  29.513190      0      0    8.0500
# 1308         1309       NaN       3  25.315435      1      1   22.3583
#
# [1309 rows x 7 columns]

# %%
# CATEGORICAL VARIABLES
titanic.select_dtypes(include=['object'])
# Out:
#                                                    Name  Gender  \
# 0                               Braund, Mr. Owen Harris    male
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                                Heikkinen, Miss. Laina  female
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                              Allen, Mr. William Henry    male
# ...                                                 ...     ...
# 1304                                 Spector, Mr. Woolf    male
# 1305                       Oliva y Ocana, Dona. Fermina  female
# 1306                       Saether, Mr. Simon Sivertsen    male
# 1307                                Ware, Mr. Frederick    male
# 1308                           Peter, Master. Michael J    male
#
#                   Ticket Cabin Embarked
# 0              A/5 21171    U0        S
# 1               PC 17599   C85        C
# 2       STON/O2. 3101282    U0        S
# ...

# %% [markdown]
# #### Set the plot style to classic and the figure size to (12,6).
# **Hint**: To set the style you can use matplotlib or seaborn functions. Do some research on the matter.

# %%
#sns.load_dataset("penguins")

#sns.set(rc={"figure.figsize":(12,6)})


plt.figure(figsize=(12,5))
plt.style.use('classic')

# %% [markdown]
# #### Use the right visulalization to show the distribution of column `Age`.

# %%
titanic["Age"].plot(kind="hist", bins=100)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# #### Use subplots and plot the distribution of the `Age`  with bins equal to 10, 20 and 50.

# %%
fig, [ax1, ax2, ax3] = plt.subplots(1,3)
titanic['Age'].plot(kind='hist', bins=10, ax=ax1)
titanic['Age'].plot(kind='hist', bins=20, ax=ax2)
titanic['Age'].plot(kind='hist', bins=50, ax=ax3)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# #### How does the bin size affect your plot?

# %%
"""
The smaller the bins are the more precise the differences within the data is portrayed.
"""

# %% [markdown]
# #### Use seaborn to show the distribution of column `Age`.

# %%
titanic = sns.load_dataset("titanic")

# %%
sns.histplot(data=titanic, x="age", bins=50)
# Out:
# <AxesSubplot:xlabel='age', ylabel='Count'>

# %% [markdown]
# #### Use the right plot to visualize column `Gender`. There are 2 ways of doing it. Do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
# Method 1 - matplotlib
plt.hist(titanic['sex'], bins = 2)
plt.show()

# %%
# Method 2 - seaborn
sns.histplot(data=titanic, x="sex", bins=2)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='Count'>

# %% [markdown]
# #### Use the right plot to visualize the column `Pclass`.

# %%
pclass_counts = titanic['pclass'].value_counts().to_frame().reset_index()
pclass_counts
# Out:
#    index  pclass
# 0      3     491
# 1      1     216
# 2      2     184

# %%
sns.barplot(data=pclass_counts, x="index", y="pclass");

# %% [markdown]
# #### We would like to have in one single plot the summary statistics of the feature `Age`. What kind of plot would you use? Plot it.

# %%
f, ax = plt.subplots(figsize=(15,6))
ax = sns.boxplot(data=titanic, x='age')

# %%
"""
The boxplot tells us about the median, the interquartile range and outliers.
"""
# Out:
# '\nThe boxplot tells us about the median, the interquartile range and outliers.\n'

# %% [markdown]
# #### What does the last plot tell you about the feature `Age`?

# %%
"""
The median age was around 28 years old and there were a few people who had a different age than 50% of the people, since they were over 65.
"""

# %% [markdown]
# #### Now in addition to the summary statistics, we want to have in the same plot the distribution of `Age`. What kind of plot would you use? Plot it.

# %%
f, ax = plt.subplots(figsize=(15,6))
ax = sns.boxplot(data=titanic, x='age')
# for patch in ax.artists:
#     patch.set_alpha(0.3)
sns.stripplot(data=titanic, x='age', alpha=0.5, size=9)
plt.show()

# %% [markdown]
# #### What additional information does the last plot provide about feature `Age`?

# %%
"""
The last plot gives gives information about the age distribution of passengers.
"""
# Out:
# '\nThe last plot gives gives information about the age distribution of passengers.\n'

# %% [markdown]
# #### We suspect that there is a linear relationship between `Fare` and `Age`. Use the right plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
# your code here

# %%
# Method 2 - seaborn
sns.regplot(data=titanic, x='age', y='fare')
plt.show()

# %% [markdown]
# #### Plot the correlation matrix using seaborn.

# %%
sns.heatmap(titanic.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %% [markdown]
# #### What are the most correlated features?

# %%
"""
The most correlated features are parch and sibsp; and adult male and alone. 
"""

# %% [markdown]
# #### Use the most appropriate plot to display the summary statistics of `Age` depending on `Pclass`.

# %%
sns.boxplot(data=titanic, x="pclass", y="age")
# Out:
# <AxesSubplot:xlabel='pclass', ylabel='age'>

# %% [markdown]
# #### Use seaborn to plot the distribution of `Age` based on the `Gender`.
# **Hint**: Use Facetgrid.

# %%
sns.boxplot(data=titanic, x="sex", y="age")
# Out:
# <AxesSubplot:xlabel='sex', ylabel='age'>
